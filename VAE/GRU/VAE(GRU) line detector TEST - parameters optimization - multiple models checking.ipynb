# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np
import os
from time import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input, Dense, Lambda, BatchNormalization, Flatten, Reshape, GRU, Conv1DTranspose
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K

from scipy.optimize import minimize
from sklearn.metrics import classification_report
from itertools import chain

# %% [markdown]
# # Load Real Data

# %%
path = "C:/Users/OPTIMUSPRIME/Desktop/Studia/Magisterka/Faints-Prediction/"
BP_filename = "BP.csv"
HR_filename = "HR.csv"

train_indices =  [str(indx[0]) for indx in pd.read_csv(path + "DATA/training_set.txt", header=None).values.tolist()]
test_indices =  [str(indx[0]) for indx in pd.read_csv(path + "DATA/test_set.txt", header=None).values.tolist()]
validation_indices =  [str(indx[0]) for indx in pd.read_csv(path + "DATA/validation_set.txt", header=None).values.tolist()]
all_indices = train_indices + test_indices + validation_indices

# %%
BP_data = pd.read_csv(path + "DATA/" + BP_filename, low_memory=False)[all_indices]
HR_data = pd.read_csv(path + "DATA/" + HR_filename, low_memory=False)[all_indices]
labels = {col: BP_data[col].iloc[0] for col in BP_data}

BP_max_value = BP_data.iloc[1:].astype(np.float32).max().max()
BP_min_value = BP_data.iloc[1:].astype(np.float32).min().min()
HR_max_value = HR_data.iloc[1:].astype(np.float32).max().max()
HR_min_value = HR_data.iloc[1:].astype(np.float32).min().min()

BP_scaler = MinMaxScaler().fit(np.array([BP_min_value, BP_max_value]).reshape(-1,1))
HR_scaler = MinMaxScaler().fit(np.array([HR_min_value, HR_max_value]).reshape(-1,1))

BP_data_scaled = BP_data.iloc[1:].astype(np.float32).copy()
BP_data_scaled[all_indices] = BP_scaler.transform(BP_data_scaled[all_indices])


HR_data_scaled = HR_data.iloc[1:].astype(np.float32).copy()
HR_data_scaled[all_indices] = HR_scaler.transform(HR_data_scaled[all_indices])

# %%
# SMOOTHING
BP_data_scaled_averaged = BP_data_scaled.rolling(60).mean()
HR_data_scaled_averaged = HR_data_scaled.rolling(60).mean()

# %% [markdown]
# # Loading Model

# %%
# path = "LINE_DETECTOR_VAE_CNN_RESULTS2/LOSS0.91_8DBS2.88_8CHS7989.89_LATENT8_STDEV0.05_BS128_E1_LR0.0005_KS16_F8_S2"
# path = "LINE_DETECTOR_VAE_CNN_RESULTS2\LOSS0.28_8DBS3.02_8CHS6984.79_LATENT8_STDEV0.05_BS128_E1_LR0.005_KS8_F48_S2"
# path = "LINE_DETECTOR_VAE_CNN_RESULTS2\LOSS0.21_8DBS3.78_8CHS4352.38_LATENT8_STDEV0.05_BS128_E20_LR0.005_KS4_F48_S2"
path = "LINE_DETECTOR_VAE_GRU_RESULTS2/LOSS0.37_8DBS4.11_8CHS3729.87_LATENT8_STDEV0.1_BS128_E10_LR0.005_ACTrelu"
bs = 128
lr = 0.005
stdev = 0.1
e = 10
ac ='relu'

original_dim = 32
input_shape = (original_dim, )
intermediate_dim = 16
latent_dim = 8

def sampling(args):
    z_mean, z_log_var = args
    batch = K.shape(z_mean)[0]
    dim = K.int_shape(z_mean)[1]
    # by default, random_normal has mean = 0 and std = 1.0
    epsilon = K.random_normal(shape=(batch, dim), stddev=stdev)
    return z_mean + K.exp(0.5 * z_log_var) * epsilon

#ENCODER
inputs = Input(shape=(original_dim, 1), name='encoder_input')
x = GRU(intermediate_dim, name='encoder_LSTM', activation=ac)(inputs)
x = BatchNormalization()(x)

z_mean = Dense(latent_dim, name='z_mean')(x)
z_log_var = Dense(latent_dim, name='z_log_var')(x)
z = Lambda(sampling, output_shape=(latent_dim, ), name='z')([z_mean, z_log_var])

encoder = Model(inputs, [z_mean, z_log_var, z], name='encoder')
# encoder.summary()

encoder.load_weights(path + "/encoder/")
# encoder.summary()

encoder.load_weights(path + "/encoder/")

# %% [markdown]
# # Generate Baseline Data

# %%
def generate_line(a, b, n=32, noise=0):
    x = np.arange(n)
    return a * x + b + np.random.normal(0, noise, n)

def generate_lines(a, bs, n_train, c, lines, labels):
    for b in bs:
        generated_lines = np.array([generate_line(a, b, noise=0.005) for _ in range(int(n_train/16))])
        generated_labels = np.array([c for _ in range(int(n_train/16))])
        if lines.size == 0:
            lines = generated_lines
            labels = generated_labels
        else:
            lines = np.concatenate((lines, generated_lines))
            labels = np.concatenate((labels, generated_labels))
    return lines, labels
    
def generate_lines_set(n_train):    
    lines = np.array([])
    labels = np.array([])

    lines, labels = generate_lines(0, [0, .4, .8, 1.2, 1.6, 2], n_train, 'g', lines, labels)
    lines, labels = generate_lines(0.01, [.2, .6, 1, 1.4, 1.8], n_train, 'r', lines, labels)
    lines, labels = generate_lines(-0.01, [.2, .6, 1, 1.4, 1.8], n_train, 'b', lines, labels)

    return np.array(lines), np.array(labels)

n_lines = 64000
n_types = 16
x_train, y_train = generate_lines_set(64000)
x_train = (x_train - np.amin(x_train)) / (np.amax(x_train) - np.amin(x_train))

# %%
index = 10
interval = int(n_lines / n_types)
print(interval)
while index < n_lines:
    plt.plot(x_train[index])
    index += interval
# Out:
# 4000

# %% [markdown]
# # Calculate Baseline

# %%
z_test, _, _ = encoder.predict(x_train, batch_size=bs)
straight_lines_8D = z_test[:24000]
means = straight_lines_8D.mean(axis=0)
principal_axis = np.linalg.svd(straight_lines_8D - means)[2][0]
baseline_point1 = np.array([0,0,0,0,0,0,0,0], np.float32)
baseline_point2 = np.array(principal_axis, np.float32)

# %%
def dist(p, q, rs):
    x = p-q
    return np.linalg.norm(
        np.outer(np.dot(rs-q, x)/np.dot(x, x), x)+q-rs,
        axis=1)

# %% [markdown]
# # Visualize 2D

# %%
z_test_2D = PCA(n_components=2).fit_transform(z_test)
straight_lines_2D = z_test_2D[:24000]
means_2D = straight_lines_2D.mean(axis=0)
principal_axis_2D = np.linalg.svd(straight_lines_2D - means_2D)[2][0]
baseline_point1_2D = np.array([0,0], np.float32)
baseline_point2_2D = np.array(principal_axis_2D, np.float32)
plt.figure(figsize=(12,8))
plt.scatter(z_test_2D[:, 0], z_test_2D[:, 1],  c=y_train)
plt.plot([-baseline_point2_2D[0], baseline_point2_2D[0]], [-baseline_point2_2D[1], baseline_point2_2D[1]])

# %% [markdown]
# # Label Validation Samples

# %%
indexes = ['375', '1', '92', '110', '158', '286', '295', '393', '460', '501', '606', '658', '675'] #375 is the longest, that's why it is in the beginning
# indexes = ['375', '393']

# %%
def label_func(index, start, end, color):
    for i in range(start, end):
        BP_HR_validation_labels[index][i] = color

BP_HR_validation_labels = dict()
BP_validation = dict()
HR_validation = dict()
for index in indexes:
    BPx = np.array(BP_data_scaled_averaged[index])
    HRx = np.array(HR_data_scaled_averaged[index])
    BPx = BPx[~np.isnan(BPx)]
    HRx = HRx[~np.isnan(HRx)]
    BPx = BPx[:-(BPx.shape[0] % 32)]
    HRx = HRx[:-(HRx.shape[0] % 32)]
    BPxs = np.array(np.array_split(BPx, int(len(BPx)/32)))
    HRxs = np.array(np.array_split(HRx, int(len(HRx)/32)))
    BP_HR_validation_labels[index] = np.array(['g']*len(BPxs))
    BP_validation[index] = BPxs
    HR_validation[index]= HRxs

# %%
index = '1'
label_func('1', 80, 81, 'r')
label_func('1', 81, 107, 'r')
label_func('1', 107, 108, 'r')
index = '92' 
label_func('92', 41, 49, 'r')
label_func('92', 142, 143, 'r')
label_func('92', 143, 154, 'r')
index = '110' 
label_func('110', 119, 120, 'r')
label_func('110', 120, 123, 'r')
index = '158' 
label_func('158', 25, 29, 'r')
label_func('158', 115, 116, 'r')
label_func('158', 116, 122, 'r')
label_func('158', 122, 123, 'r')
index = '286' 
label_func('286', 63, 65, 'r')
label_func('286', 65, 67, 'r')
label_func('286', 123, 124, 'r')
label_func('286', 124, 129, 'r')
label_func('286', 129, 131, 'r')
label_func('286', 131, 134, 'r')
index = '295' 
label_func('295', 131, 134, 'r')
label_func('295', 134, 144, 'r')
index = '375'
label_func('375', 40, 47, 'r')
label_func('375', 129, 133, 'r')
label_func('375', 133, 141, 'r')
label_func('375', 141, 144, 'r')
label_func('375', 162, 167, 'r')
index = '393' 
label_func('393', 32, 36, 'r')
label_func('393', 36, 37, 'r')
index = '460' 
label_func('460', 50, 58, 'r')
label_func('460', 58, 59, 'r')
index = '501'
label_func('501', 119, 120, 'r')
label_func('501', 120, 124, 'r')
label_func('501', 124, 125, 'r')
index = '606'
label_func('606', 60, 61, 'r')
label_func('606', 61, 70, 'r')
label_func('606', 70, 72, 'r')
index = '658', 
label_func('658', 36, 53, 'r')
label_func('658', 53, 55, 'r')
index ='675', 
label_func('675', 82, 101, 'r')
label_func('675', 101, 104, 'r')

# %% [markdown]
# # Auxiliary Functions

# %%
def sample_timeseries(x):
    x = np.array(x)
    x = x[~np.isnan(x)]
    if x.shape[0] % 32 != 0:
        x = x[:-(x.shape[0] % 32)]
    return np.array(np.array_split(x, int(len(x)/32)))


N_SAMPLES_MEMORY = 5
BP_SEVERITY_ACC = np.zeros(N_SAMPLES_MEMORY)
HR_SEVERITY_ACC = np.zeros(N_SAMPLES_MEMORY)
BP_HR_SEVERITY_ACC = np.zeros(N_SAMPLES_MEMORY)

def zero_accumulators():
    global BP_SEVERITY_ACC, HR_SEVERITY_ACC, BP_HR_SEVERITY_ACC
    BP_SEVERITY_ACC = np.zeros(N_SAMPLES_MEMORY)
    HR_SEVERITY_ACC = np.zeros(N_SAMPLES_MEMORY)
    BP_HR_SEVERITY_ACC = np.zeros(N_SAMPLES_MEMORY)
    
def classifier(y_pred, a, b):
    global BP_SEVERITY_ACC, HR_SEVERITY_ACC, BP_HR_SEVERITY_ACC
    BP_anomaly_score = y_pred[-1][0]
    HR_anomaly_score = y_pred[-1][1]
    HR_SEVERITY_ACC = np.append(HR_SEVERITY_ACC, HR_anomaly_score)
    BP_SEVERITY_ACC = np.append(BP_SEVERITY_ACC, BP_anomaly_score)
    BP_HR_SEVERITY_ACC = np.append(BP_HR_SEVERITY_ACC, HR_anomaly_score + BP_anomaly_score)
    if HR_anomaly_score > a or BP_anomaly_score > a or HR_anomaly_score + BP_anomaly_score > a or np.mean(HR_SEVERITY_ACC[-5:]) > b or np.mean(BP_SEVERITY_ACC[-5:]) > b or np.mean(BP_HR_SEVERITY_ACC[-5:]) > b:
        return 'r'
    else:
        return 'g'    

def write_to_file(path, header, *args):
    with open(path, 'a') as file:
        if os.stat(path).st_size == 0:
            file.write(header)
        text = str()
        for item in args:
            text += str(item) + '\t'
        file.write('\n' + text)

def count_samples(timeseries):
    n_of_not_nans = np.count_nonzero(~np.isnan(timeseries))
    return int(n_of_not_nans/32)

def calculate_metrics(direct_threshold, average_threshold, labels_true, labels_pred, write_file):
    class_report = classification_report(labels_true, labels_pred, output_dict=True)
    acc = round(class_report['accuracy'], 4)
    red_f1 = round(class_report['r']['f1-score'], 4)
    red_precision = round(class_report['r']['precision'], 4)
    red_recall = round(class_report['r']['recall'], 4)
    green_f1 = round(class_report['g']['f1-score'], 4)
    green_precision = round(class_report['g']['precision'], 4)
    green_recall = round(class_report['g']['recall'], 4)
    if write_file:
        write_to_file("GRU_best_model_thresholds_grid_search.tsv", 
                      "Direct Threshold\tAveraged Threshold\tAccuracy\tRed F1\tRed Precision\tRed Recall\tGreen F1\tGreen Precision\tGreen Recall",
                      direct_threshold,
                      average_threshold,
                      acc,
                      red_f1,
                      red_precision,
                      red_recall,
                      green_f1,
                      green_precision,
                      green_recall) 
    return red_f1

def evaluate_model(y_pred, direct_threshold, average_threshold, write_file):
    start = time()
    labels_pred = np.array([])
    
    for i in indexes:
        zero_accumulators()
        n_of_samples_in_timeseries = count_samples(BP_data_scaled_averaged[i])
        for j in range(n_of_samples_in_timeseries):   
            severity = classifier(y_pred[i][:j+1], direct_threshold, average_threshold)
            labels_pred = np.append(labels_pred, severity)
    labels_true = np.array(list(chain(*BP_HR_validation_labels.values())), dtype=str)  
    example_metric = calculate_metrics(direct_threshold, average_threshold, labels_true, labels_pred, write_file)
    return example_metric
#     print(f"Red F1: {example_metric:.4f}, DT: {direct_threshold:.3f}, AT: {average_threshold:.3f}, time:{(time() - start):.2f}s")

# %% [markdown]
# # Parameters optimization

# %%
direct_thresholds = np.array(range(20, 202, 2)) / 1000
average_thresholds = np.array(range(20, 202, 2)) / 1000
print(direct_thresholds)
print(len(direct_thresholds) * len(average_thresholds))
# Out:
# [0.02  0.022 0.024 0.026 0.028 0.03  0.032 0.034 0.036 0.038 0.04  0.042
#  0.044 0.046 0.048 0.05  0.052 0.054 0.056 0.058 0.06  0.062 0.064 0.066
#  0.068 0.07  0.072 0.074 0.076 0.078 0.08  0.082 0.084 0.086 0.088 0.09
#  0.092 0.094 0.096 0.098 0.1   0.102 0.104 0.106 0.108 0.11  0.112 0.114
#  0.116 0.118 0.12  0.122 0.124 0.126 0.128 0.13  0.132 0.134 0.136 0.138
#  0.14  0.142 0.144 0.146 0.148 0.15  0.152 0.154 0.156 0.158 0.16  0.162
#  0.164 0.166 0.168 0.17  0.172 0.174 0.176 0.178 0.18  0.182 0.184 0.186
#  0.188 0.19  0.192 0.194 0.196 0.198 0.2  ]
# 8281

# %%
def calc_predicted_values(BP_data, HR_data, model, baseline_point1, baseline_point2):
    y_pred = dict()
    for i in indexes:
        y_pred_sample = []
        HR_sampled = sample_timeseries(HR_data[i])
        BP_sampled = sample_timeseries(BP_data[i]) 
        n_of_samples_in_timeseries = len(BP_sampled)
        BP_points_8D, _, _ = model.predict(BP_sampled)
        HR_points_8D, _, _ = model.predict(HR_sampled)
        BP_distances = dist(baseline_point1, baseline_point2, BP_points_8D)
        HR_distances = dist(baseline_point1, baseline_point2, HR_points_8D)
        y_pred_sample = np.array([[BP_dist, HR_dist] for BP_dist, HR_dist in zip(BP_distances, HR_distances)])
        y_pred[i] = y_pred_sample
    return y_pred

def grid_search(direct_thresholds, average_thresholds, write_file=False):
    print("Calculating predictions ...")
    y_pred = calc_predicted_values(BP_data_scaled_averaged, HR_data_scaled_averaged, encoder, baseline_point1, baseline_point2)
    print("Calculating predictions done.")
    metrics_cache = []
    for direct_threshold in direct_thresholds:
        for average_threshold in average_thresholds:
            metrics_cache.append(evaluate_model(y_pred, direct_threshold, average_threshold, write_file))
    return max(metrics_cache)

# grid_search(direct_thresholds, average_thresholds, True)

# %% [markdown]
# # Plotting metrics

# %%
def plot_metric(AA, BB, CC):
    def f(AA, BB):
        C = np.zeros((len(AA), len(BB)))
        for i in range(len(AA)):
            for j in range(len(BB)):
                C[i, j] = CC[(AA[i], BB[j])]
        return C    
    A, B = np.meshgrid(AA, BB)
    C = f(AA, BB)
    plt.figure(figsize=(12,8))
    plt.contourf(A, B, C, levels=100, cmap='jet')
    plt.clim(0.3, 0.7)
    plt.colorbar()
    
def load_metric_and_plot(file_path, metric_name):
    metrics = pd.read_csv(file_path, delimiter='\t', index_col=False)
    direct_thresholds = sorted(metrics['Direct Threshold'].unique())
    average_thresholds = sorted(metrics['Averaged Threshold'].unique())
    selected_metric = dict()
    for index, row in metrics.iterrows():
        selected_metric[(row['Direct Threshold'], row['Averaged Threshold'])] = row[metric_name]
    plot_metric(direct_thresholds, average_thresholds, selected_metric)

load_metric_and_plot("GRU_best_model_thresholds_grid_search.tsv", "Red F1")

# %% [markdown]
# # Multiple models parameters optimization

# %%
def extract_params(path):
    path_splitted = path.split("_")
    stdev = float(path_splitted[4][5:])
    bs = int(path_splitted[5][2:])
    e = int(path_splitted[6][1:])
    lr = float(path_splitted[7][2:])
    ac = path_splitted[8][3:]
    return stdev, bs, e, lr, ac

def build_model(path, stdev, bs, e, lr, ac):
    original_dim = 32
    input_shape = (original_dim, )
    intermediate_dim = 16
    latent_dim = 8

    def sampling(args):
        z_mean, z_log_var = args
        batch = K.shape(z_mean)[0]
        dim = K.int_shape(z_mean)[1]
        # by default, random_normal has mean = 0 and std = 1.0
        epsilon = K.random_normal(shape=(batch, dim), stddev=stdev)
        return z_mean + K.exp(0.5 * z_log_var) * epsilon

    #ENCODER
    inputs = Input(shape=(original_dim, 1), name='encoder_input')
    x = GRU(intermediate_dim, name='encoder_LSTM', activation=ac)(inputs)
    x = BatchNormalization()(x)

    z_mean = Dense(latent_dim, name='z_mean')(x)
    z_log_var = Dense(latent_dim, name='z_log_var')(x)
    z = Lambda(sampling, output_shape=(latent_dim, ), name='z')([z_mean, z_log_var])

    encoder = Model(inputs, [z_mean, z_log_var, z], name='encoder')
    # encoder.summary()

    encoder.load_weights(path + "/encoder/")
    return encoder

direct_thresholds = np.array(range(40, 125, 5)) / 1000
average_thresholds = np.array(range(40, 125, 5)) / 1000
print(direct_thresholds)
# Out:
# [0.04  0.045 0.05  0.055 0.06  0.065 0.07  0.075 0.08  0.085 0.09  0.095
#  0.1   0.105 0.11  0.115 0.12 ]

# %%
folders = [name for name in os.listdir("temp/")]

for folder in folders:
    stdev, bs, e, lr, ac = extract_params(folder)
    encoder = build_model("temp/" + folder, stdev, bs, e, lr, ac)
    
    z_test, _, _ = encoder.predict(x_train, batch_size=bs)
    straight_lines_8D = z_test[:24000]
    means = straight_lines_8D.mean(axis=0)
    principal_axis = np.linalg.svd(straight_lines_8D - means)[2][0]
    baseline_point1 = np.array([0,0,0,0,0,0,0,0], np.float32)
    baseline_point2 = np.array(principal_axis, np.float32)
    
    max_metric = grid_search(direct_thresholds, average_thresholds)
    write_to_file("metrics_results.tsv",
                 "Path\tRed F1",
                 folder,
                 max_metric)
# Out:
# C:\Programs\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-00ca28952e61> in <module>
#       2
#       3 for folder in folders:
# ----> 4     stdev, bs, e, lr, ac = extract_params(folder)
#       5     encoder = build_model("temp/" + folder, stdev, bs, e, lr, ac)
#       6
#
# <ipython-input-24-1b8ba70c9359> in extract_params(path)
#       1 def extract_params(path):
#       2     path_splitted = path.split("_")
# ----> 3     stdev = float(path_splitted[4][5:])
#       4     bs = int(path_splitted[5][2:])
#       5     e = int(path_splitted[6][1:])
#
# IndexError: list index out of range

# %% [markdown]
# # Save Timeseries Classification

# %%
y_pred = calc_predicted_values(BP_data_scaled_averaged, HR_data_scaled_averaged, encoder, baseline_point1, baseline_point2)

grid_search_results = pd.read_csv("GRU_best_model_thresholds_grid_search.tsv", delimiter='\t', index_col=False)
best_parameters = grid_search_results.loc[grid_search_results['Red F1'] == max(grid_search_results['Red F1'])]
direct_threshold = best_parameters['Direct Threshold'].iloc[0]
average_threshold = best_parameters['Averaged Threshold'].iloc[0]
print(f"Chosen direct threshold: {direct_threshold}\nChosen average threshold: {average_threshold}")

predicted_labels = pd.DataFrame()
counter = 0
for i in indexes:
    counter = counter + 1
    labels = [] 
    zero_accumulators()
    HR = sample_timeseries(HR_data_scaled_averaged[i])
    BP = sample_timeseries(BP_data_scaled_averaged[i])
    n_of_samples = len(BP)
    for j in range(n_of_samples):
        labels.append(classifier(y_pred[i][:j+1], direct_threshold, average_threshold))
    predicted_labels[i] = pd.Series(labels)
    
predicted_labels.to_csv('best_model_best_params_predicted_labels.tsv', sep='\t')
# Out:
# Chosen direct threshold: 0.136
# Chosen average threshold: 0.11599999999999999

# %%
for b in bb:
    for a in aa:
        calc_accuracy_for_params([a, b])
# Out:
# Accuracy: 0.8931, Green F1: 0.9377, Red F1: 0.6241, a: 0.050, b: 0.038, time:87.36s
# Accuracy: 0.8944, Green F1: 0.9386, Red F1: 0.6235, a: 0.052, b: 0.038, time:87.90s
# Accuracy: 0.8985, Green F1: 0.9412, Red F1: 0.6290, a: 0.054, b: 0.038, time:88.02s
# Accuracy: 0.8998, Green F1: 0.9421, Red F1: 0.6284, a: 0.056, b: 0.038, time:87.57s
# Accuracy: 0.9025, Green F1: 0.9438, Red F1: 0.6329, a: 0.058, b: 0.038, time:88.31s
# Accuracy: 0.9018, Green F1: 0.9434, Red F1: 0.6294, a: 0.060, b: 0.038, time:88.10s
# Accuracy: 0.8991, Green F1: 0.9415, Red F1: 0.6324, a: 0.050, b: 0.039, time:88.01s
# Accuracy: 0.9005, Green F1: 0.9425, Red F1: 0.6318, a: 0.052, b: 0.039, time:88.38s
# Accuracy: 0.9045, Green F1: 0.9450, Red F1: 0.6378, a: 0.054, b: 0.039, time:88.77s
# Accuracy: 0.9059, Green F1: 0.9459, Red F1: 0.6373, a: 0.056, b: 0.039, time:88.07s
# Accuracy: 0.9085, Green F1: 0.9476, Red F1: 0.6421, a: 0.058, b: 0.039, time:88.18s
# Accuracy: 0.9079, Green F1: 0.9472, Red F1: 0.6385, a: 0.060, b: 0.039, time:88.34s
# Accuracy: 0.8998, Green F1: 0.9424, Red F1: 0.6170, a: 0.050, b: 0.040, time:87.90s
# Accuracy: 0.9011, Green F1: 0.9433, Red F1: 0.6162, a: 0.052, b: 0.040, time:88.03s
# Accuracy: 0.9052, Green F1: 0.9458, Red F1: 0.6220, a: 0.054, b: 0.040, time:88.11s
# Accuracy: 0.9072, Green F1: 0.9471, Red F1: 0.6230, a: 0.056, b: 0.040, time:90.29s
# Accuracy: 0.9106, Green F1: 0.9491, Red F1: 0.6295, a: 0.058, b: 0.040, time:88.91s
# Accuracy: 0.9099, Green F1: 0.9488, Red F1: 0.6257, a: 0.060, b: 0.040, time:91.71s
# Accuracy: 0.9065, Green F1: 0.9465, Red F1: 0.6313, a: 0.050, b: 0.041, time:90.78s
# Accuracy: 0.9079, Green F1: 0.9474, Red F1: 0.6307, a: 0.052, b: 0.041, time:91.47s
# Accuracy: 0.9126, Green F1: 0.9503, Red F1: 0.6389, a: 0.054, b: 0.041, time:97.72s
# Accuracy: 0.9146, Green F1: 0.9515, Red F1: 0.6402, a: 0.056, b: 0.041, time:104.58s
# Accuracy: 0.9173, Green F1: 0.9532, Red F1: 0.6435, a: 0.058, b: 0.041, time:107.74s
# Accuracy: 0.9159, Green F1: 0.9525, Red F1: 0.6356, a: 0.060, b: 0.041, time:106.50s
# Accuracy: 0.9065, Green F1: 0.9467, Red F1: 0.6213, a: 0.050, b: 0.042, time:100.03s
# Accuracy: 0.9072, Green F1: 0.9472, Red F1: 0.6167, a: 0.052, b: 0.042, time:101.77s
# Accuracy: 0.9119, Green F1: 0.9501, Red F1: 0.6246, a: 0.054, b: 0.042, time:105.06s
# Accuracy: 0.9139, Green F1: 0.9514, Red F1: 0.6235, a: 0.056, b: 0.042, time:98.95s
# Accuracy: 0.9159, Green F1: 0.9527, Red F1: 0.6224, a: 0.058, b: 0.042, time:97.13s
# Accuracy: 0.9146, Green F1: 0.9520, Red F1: 0.6140, a: 0.060, b: 0.042, time:99.31s

# %%
for b in bb:
    for a in aa:
        calc_accuracy_for_params([a, b])
# Out:
# Accuracy: 0.6940, Red Precision: 0.2867, a: 0.040, b: 0.030, time:87.36s
# Accuracy: 0.7095, Red Precision: 0.2978, a: 0.045, b: 0.030, time:85.28s
# Accuracy: 0.7149, Red Precision: 0.3007, a: 0.050, b: 0.030, time:88.19s
# Accuracy: 0.7149, Red Precision: 0.2993, a: 0.055, b: 0.030, time:84.57s
# Accuracy: 0.7162, Red Precision: 0.3004, a: 0.060, b: 0.030, time:84.84s
# Accuracy: 0.8238, Red Precision: 0.4242, a: 0.040, b: 0.035, time:84.75s
# Accuracy: 0.8507, Red Precision: 0.4774, a: 0.045, b: 0.035, time:85.10s
# Accuracy: 0.8662, Red Precision: 0.5162, a: 0.050, b: 0.035, time:87.61s
# Accuracy: 0.8682, Red Precision: 0.5226, a: 0.055, b: 0.035, time:84.78s
# Accuracy: 0.8709, Red Precision: 0.5312, a: 0.060, b: 0.035, time:84.71s

# %%
for b in bb:
    for a in aa:
        acc = classification_reports[(a,b)]['accuracy']
        red_f1 = classification_reports[(a,b)]['r']['f1-score']
        green_f1 = classification_reports[(a,b)]['g']['f1-score']
        print(f"Accuracy: {acc:.4f}, Green F1: {green_f1:.4f}, Red F1: {red_f1:.4f}, a: {a:.3f}, b: {b:.3f}")
# Out:
# Accuracy: 0.6940, Green F1: 0.7920, Red F1: 0.4219, a: 0.040, b: 0.030
# Accuracy: 0.7095, Green F1: 0.8047, Red F1: 0.4331, a: 0.045, b: 0.030
# Accuracy: 0.7149, Green F1: 0.8094, Red F1: 0.4347, a: 0.050, b: 0.030
# Accuracy: 0.7149, Green F1: 0.8097, Red F1: 0.4316, a: 0.055, b: 0.030
# Accuracy: 0.7162, Green F1: 0.8108, Red F1: 0.4328, a: 0.060, b: 0.030
# Accuracy: 0.8238, Green F1: 0.8913, Red F1: 0.5355, a: 0.040, b: 0.035
# Accuracy: 0.8507, Green F1: 0.9096, Red F1: 0.5714, a: 0.045, b: 0.035
# Accuracy: 0.8662, Green F1: 0.9200, Red F1: 0.5897, a: 0.050, b: 0.035
# Accuracy: 0.8682, Green F1: 0.9216, Red F1: 0.5865, a: 0.055, b: 0.035
# Accuracy: 0.8709, Green F1: 0.9235, Red F1: 0.5862, a: 0.060, b: 0.035

# %%
for b in bb:
    for a in aa:
        calc_accuracy_for_params([a, b])
# Out:
# Accuracy: 0.8547, Red Precision: 0.4856, a: 0.040, b: 0.040, time:85.89s
# Accuracy: 0.8837, Red Precision: 0.5792, a: 0.045, b: 0.040, time:86.83s
# Accuracy: 0.8998, Red Precision: 0.6630, a: 0.050, b: 0.040, time:87.42s
# Accuracy: 0.9059, Red Precision: 0.7073, a: 0.055, b: 0.040, time:85.21s
# Accuracy: 0.9099, Red Precision: 0.7467, a: 0.060, b: 0.040, time:85.02s
# Accuracy: 0.9079, Red Precision: 0.7415, a: 0.065, b: 0.040, time:84.98s
# Accuracy: 0.9072, Red Precision: 0.7431, a: 0.070, b: 0.040, time:85.45s
# Accuracy: 0.9072, Red Precision: 0.7465, a: 0.075, b: 0.040, time:86.95s
# Accuracy: 0.9065, Red Precision: 0.7447, a: 0.080, b: 0.040, time:86.44s
# Accuracy: 0.8554, Red Precision: 0.4862, a: 0.040, b: 0.045, time:85.22s
# Accuracy: 0.8830, Red Precision: 0.5895, a: 0.045, b: 0.045, time:85.46s
# Accuracy: 0.8998, Red Precision: 0.7063, a: 0.050, b: 0.045, time:86.77s
# Accuracy: 0.9052, Red Precision: 0.7815, a: 0.055, b: 0.045, time:85.74s
# Accuracy: 0.9065, Red Precision: 0.8485, a: 0.060, b: 0.045, time:85.99s
# Accuracy: 0.9045, Red Precision: 0.8438, a: 0.065, b: 0.045, time:86.64s
# Accuracy: 0.9045, Red Precision: 0.8587, a: 0.070, b: 0.045, time:85.93s
# Accuracy: 0.9032, Red Precision: 0.8636, a: 0.075, b: 0.045, time:85.89s
# Accuracy: 0.9018, Red Precision: 0.8605, a: 0.080, b: 0.045, time:85.39s
# Accuracy: 0.8561, Red Precision: 0.4877, a: 0.040, b: 0.050, time:84.14s
# Accuracy: 0.8837, Red Precision: 0.5989, a: 0.045, b: 0.050, time:84.29s
# Accuracy: 0.8998, Red Precision: 0.7287, a: 0.050, b: 0.050, time:84.79s
# Accuracy: 0.9052, Red Precision: 0.8190, a: 0.055, b: 0.050, time:84.24s
# Accuracy: 0.9065, Red Precision: 0.9157, a: 0.060, b: 0.050, time:86.80s
# Accuracy: 0.9052, Red Precision: 0.9241, a: 0.065, b: 0.050, time:84.30s
# Accuracy: 0.9038, Red Precision: 0.9452, a: 0.070, b: 0.050, time:85.26s
# Accuracy: 0.9025, Red Precision: 0.9565, a: 0.075, b: 0.050, time:88.53s
# Accuracy: 0.9011, Red Precision: 0.9552, a: 0.080, b: 0.050, time:89.07s
# Accuracy: 0.8547, Red Precision: 0.4832, a: 0.040, b: 0.055, time:87.44s
# Accuracy: 0.8810, Red Precision: 0.5917, a: 0.045, b: 0.055, time:87.93s
# Accuracy: 0.8958, Red Precision: 0.7227, a: 0.050, b: 0.055, time:85.96s
# Accuracy: 0.8998, Red Precision: 0.8172, a: 0.055, b: 0.055, time:86.94s
# Accuracy: 0.8998, Red Precision: 0.9275, a: 0.060, b: 0.055, time:85.63s
# Accuracy: 0.8985, Red Precision: 0.9385, a: 0.065, b: 0.055, time:91.91s
# Accuracy: 0.8971, Red Precision: 0.9661, a: 0.070, b: 0.055, time:96.86s
# Accuracy: 0.8958, Red Precision: 0.9818, a: 0.075, b: 0.055, time:86.47s
# Accuracy: 0.8944, Red Precision: 0.9811, a: 0.080, b: 0.055, time:86.60s
# Accuracy: 0.8521, Red Precision: 0.4744, a: 0.040, b: 0.060, time:85.20s
# Accuracy: 0.8783, Red Precision: 0.5818, a: 0.045, b: 0.060, time:85.34s
# Accuracy: 0.8931, Red Precision: 0.7130, a: 0.050, b: 0.060, time:85.70s
# Accuracy: 0.8971, Red Precision: 0.8090, a: 0.055, b: 0.060, time:87.36s
# Accuracy: 0.8964, Red Precision: 0.9219, a: 0.060, b: 0.060, time:87.74s
# Accuracy: 0.8951, Red Precision: 0.9333, a: 0.065, b: 0.060, time:85.58s
# Accuracy: 0.8937, Red Precision: 0.9630, a: 0.070, b: 0.060, time:85.58s
# Accuracy: 0.8924, Red Precision: 0.9800, a: 0.075, b: 0.060, time:86.87s
# Accuracy: 0.8911, Red Precision: 0.9792, a: 0.080, b: 0.060, time:87.47s
# Accuracy: 0.8514, Red Precision: 0.4721, a: 0.040, b: 0.065, time:89.89s
# Accuracy: 0.8776, Red Precision: 0.5793, a: 0.045, b: 0.065, time:86.14s
# Accuracy: 0.8924, Red Precision: 0.7105, a: 0.050, b: 0.065, time:98.97s
# Accuracy: 0.8964, Red Precision: 0.8068, a: 0.055, b: 0.065, time:85.86s
# Accuracy: 0.8944, Red Precision: 0.9180, a: 0.060, b: 0.065, time:96.93s
# Accuracy: 0.8931, Red Precision: 0.9298, a: 0.065, b: 0.065, time:85.37s
# Accuracy: 0.8917, Red Precision: 0.9608, a: 0.070, b: 0.065, time:84.96s
# Accuracy: 0.8904, Red Precision: 0.9787, a: 0.075, b: 0.065, time:86.71s
# Accuracy: 0.8890, Red Precision: 0.9778, a: 0.080, b: 0.065, time:85.13s
# Accuracy: 0.8507, Red Precision: 0.4698, a: 0.040, b: 0.070, time:85.05s
# Accuracy: 0.8769, Red Precision: 0.5767, a: 0.045, b: 0.070, time:84.95s
# Accuracy: 0.8911, Red Precision: 0.7054, a: 0.050, b: 0.070, time:85.72s
# Accuracy: 0.8937, Red Precision: 0.7976, a: 0.055, b: 0.070, time:85.96s
# Accuracy: 0.8917, Red Precision: 0.9123, a: 0.060, b: 0.070, time:85.65s
# Accuracy: 0.8897, Red Precision: 0.9231, a: 0.065, b: 0.070, time:86.31s
# Accuracy: 0.8884, Red Precision: 0.9565, a: 0.070, b: 0.070, time:86.27s
# Accuracy: 0.8863, Red Precision: 0.9756, a: 0.075, b: 0.070, time:86.81s
# Accuracy: 0.8843, Red Precision: 0.9737, a: 0.080, b: 0.070, time:115.36s
# Accuracy: 0.8514, Red Precision: 0.4719, a: 0.040, b: 0.075, time:86.34s
# Accuracy: 0.8763, Red Precision: 0.5750, a: 0.045, b: 0.075, time:85.29s
# Accuracy: 0.8904, Red Precision: 0.7064, a: 0.050, b: 0.075, time:84.61s
# Accuracy: 0.8931, Red Precision: 0.8025, a: 0.055, b: 0.075, time:84.58s
# Accuracy: 0.8911, Red Precision: 0.9259, a: 0.060, b: 0.075, time:84.94s
# Accuracy: 0.8884, Red Precision: 0.9375, a: 0.065, b: 0.075, time:84.48s
# Accuracy: 0.8870, Red Precision: 0.9762, a: 0.070, b: 0.075, time:85.22s
# Accuracy: 0.8850, Red Precision: 1.0000, a: 0.075, b: 0.075, time:86.58s
# Accuracy: 0.8823, Red Precision: 1.0000, a: 0.080, b: 0.075, time:85.73s
# Accuracy: 0.8514, Red Precision: 0.4719, a: 0.040, b: 0.080, time:85.70s
# Accuracy: 0.8756, Red Precision: 0.5723, a: 0.045, b: 0.080, time:86.33s
# Accuracy: 0.8897, Red Precision: 0.7037, a: 0.050, b: 0.080, time:86.94s
# Accuracy: 0.8924, Red Precision: 0.8000, a: 0.055, b: 0.080, time:84.92s
# Accuracy: 0.8904, Red Precision: 0.9245, a: 0.060, b: 0.080, time:85.99s
# Accuracy: 0.8877, Red Precision: 0.9362, a: 0.065, b: 0.080, time:85.64s
# Accuracy: 0.8863, Red Precision: 0.9756, a: 0.070, b: 0.080, time:86.72s
# Accuracy: 0.8837, Red Precision: 1.0000, a: 0.075, b: 0.080, time:85.79s
# Accuracy: 0.8803, Red Precision: 1.0000, a: 0.080, b: 0.080, time:86.70s

# %%
for b in bb:
    for a in aa:
        acc = classification_reports[(a,b)]['accuracy']
        red_f1 = classification_reports[(a,b)]['r']['f1-score']
        green_f1 = classification_reports[(a,b)]['g']['f1-score']
        print(f"Accuracy: {acc:.4f}, Green F1: {green_f1:.4f}, Red F1: {red_f1:.4f}, a: {a:.3f}, b: {b:.3f}")
# Out:
# Accuracy: 0.8547, Green F1: 0.9132, Red F1: 0.5556, a: 0.040, b: 0.040
# Accuracy: 0.8837, Green F1: 0.9320, Red F1: 0.5967, a: 0.045, b: 0.040
# Accuracy: 0.8998, Green F1: 0.9424, Red F1: 0.6170, a: 0.050, b: 0.040
# Accuracy: 0.9059, Green F1: 0.9462, Red F1: 0.6237, a: 0.055, b: 0.040
# Accuracy: 0.9099, Green F1: 0.9488, Red F1: 0.6257, a: 0.060, b: 0.040
# Accuracy: 0.9079, Green F1: 0.9477, Red F1: 0.6141, a: 0.065, b: 0.040
# Accuracy: 0.9072, Green F1: 0.9474, Red F1: 0.6080, a: 0.070, b: 0.040
# Accuracy: 0.9072, Green F1: 0.9474, Red F1: 0.6057, a: 0.075, b: 0.040
# Accuracy: 0.9065, Green F1: 0.9470, Red F1: 0.6017, a: 0.080, b: 0.040
# Accuracy: 0.8554, Green F1: 0.9144, Red F1: 0.5336, a: 0.040, b: 0.045
# Accuracy: 0.8830, Green F1: 0.9325, Red F1: 0.5628, a: 0.045, b: 0.045
# Accuracy: 0.8998, Green F1: 0.9432, Red F1: 0.5755, a: 0.050, b: 0.045
# Accuracy: 0.9052, Green F1: 0.9467, Red F1: 0.5688, a: 0.055, b: 0.045
# Accuracy: 0.9065, Green F1: 0.9479, Red F1: 0.5472, a: 0.060, b: 0.045
# Accuracy: 0.9045, Green F1: 0.9468, Red F1: 0.5329, a: 0.065, b: 0.045
# Accuracy: 0.9045, Green F1: 0.9469, Red F1: 0.5267, a: 0.070, b: 0.045
# Accuracy: 0.9032, Green F1: 0.9462, Red F1: 0.5135, a: 0.075, b: 0.045
# Accuracy: 0.9018, Green F1: 0.9455, Red F1: 0.5034, a: 0.080, b: 0.045
# Accuracy: 0.8561, Green F1: 0.9151, Red F1: 0.5265, a: 0.040, b: 0.050
# Accuracy: 0.8837, Green F1: 0.9332, Red F1: 0.5506, a: 0.045, b: 0.050
# Accuracy: 0.8998, Green F1: 0.9435, Red F1: 0.5579, a: 0.050, b: 0.050
# Accuracy: 0.9052, Green F1: 0.9470, Red F1: 0.5495, a: 0.055, b: 0.050
# Accuracy: 0.9065, Green F1: 0.9482, Red F1: 0.5223, a: 0.060, b: 0.050
# Accuracy: 0.9052, Green F1: 0.9475, Red F1: 0.5087, a: 0.065, b: 0.050
# Accuracy: 0.9038, Green F1: 0.9469, Red F1: 0.4911, a: 0.070, b: 0.050
# Accuracy: 0.9025, Green F1: 0.9462, Red F1: 0.4765, a: 0.075, b: 0.050
# Accuracy: 0.9011, Green F1: 0.9455, Red F1: 0.4655, a: 0.080, b: 0.050
# Accuracy: 0.8547, Green F1: 0.9146, Red F1: 0.5157, a: 0.040, b: 0.055
# Accuracy: 0.8810, Green F1: 0.9318, Red F1: 0.5305, a: 0.045, b: 0.055
# Accuracy: 0.8958, Green F1: 0.9414, Red F1: 0.5260, a: 0.050, b: 0.055
# Accuracy: 0.8998, Green F1: 0.9443, Red F1: 0.5050, a: 0.055, b: 0.055
# Accuracy: 0.8998, Green F1: 0.9448, Red F1: 0.4621, a: 0.060, b: 0.055
# Accuracy: 0.8985, Green F1: 0.9441, Red F1: 0.4469, a: 0.065, b: 0.055
# Accuracy: 0.8971, Green F1: 0.9435, Red F1: 0.4270, a: 0.070, b: 0.055
# Accuracy: 0.8958, Green F1: 0.9428, Red F1: 0.4106, a: 0.075, b: 0.055
# Accuracy: 0.8944, Green F1: 0.9421, Red F1: 0.3985, a: 0.080, b: 0.055
# Accuracy: 0.8521, Green F1: 0.9131, Red F1: 0.5023, a: 0.040, b: 0.060
# Accuracy: 0.8783, Green F1: 0.9304, Red F1: 0.5147, a: 0.045, b: 0.060
# Accuracy: 0.8931, Green F1: 0.9400, Red F1: 0.5077, a: 0.050, b: 0.060
# Accuracy: 0.8971, Green F1: 0.9428, Red F1: 0.4848, a: 0.055, b: 0.060
# Accuracy: 0.8964, Green F1: 0.9430, Red F1: 0.4338, a: 0.060, b: 0.060
# Accuracy: 0.8951, Green F1: 0.9424, Red F1: 0.4179, a: 0.065, b: 0.060
# Accuracy: 0.8937, Green F1: 0.9417, Red F1: 0.3969, a: 0.070, b: 0.060
# Accuracy: 0.8924, Green F1: 0.9411, Red F1: 0.3798, a: 0.075, b: 0.060
# Accuracy: 0.8911, Green F1: 0.9404, Red F1: 0.3672, a: 0.080, b: 0.060
# Accuracy: 0.8514, Green F1: 0.9128, Red F1: 0.4989, a: 0.040, b: 0.065
# Accuracy: 0.8776, Green F1: 0.9301, Red F1: 0.5108, a: 0.045, b: 0.065
# Accuracy: 0.8924, Green F1: 0.9397, Red F1: 0.5031, a: 0.050, b: 0.065
# Accuracy: 0.8964, Green F1: 0.9425, Red F1: 0.4797, a: 0.055, b: 0.065
# Accuracy: 0.8944, Green F1: 0.9420, Red F1: 0.4164, a: 0.060, b: 0.065
# Accuracy: 0.8931, Green F1: 0.9413, Red F1: 0.4000, a: 0.065, b: 0.065
# Accuracy: 0.8917, Green F1: 0.9407, Red F1: 0.3784, a: 0.070, b: 0.065
# Accuracy: 0.8904, Green F1: 0.9401, Red F1: 0.3608, a: 0.075, b: 0.065
# Accuracy: 0.8890, Green F1: 0.9394, Red F1: 0.3478, a: 0.080, b: 0.065
# Accuracy: 0.8507, Green F1: 0.9124, Red F1: 0.4955, a: 0.040, b: 0.070
# Accuracy: 0.8769, Green F1: 0.9297, Red F1: 0.5067, a: 0.045, b: 0.070
# Accuracy: 0.8911, Green F1: 0.9390, Red F1: 0.4938, a: 0.050, b: 0.070
# Accuracy: 0.8937, Green F1: 0.9411, Red F1: 0.4589, a: 0.055, b: 0.070
# Accuracy: 0.8917, Green F1: 0.9406, Red F1: 0.3925, a: 0.060, b: 0.070
# Accuracy: 0.8897, Green F1: 0.9396, Red F1: 0.3692, a: 0.065, b: 0.070
# Accuracy: 0.8884, Green F1: 0.9390, Red F1: 0.3465, a: 0.070, b: 0.070
# Accuracy: 0.8863, Green F1: 0.9380, Red F1: 0.3213, a: 0.075, b: 0.070
# Accuracy: 0.8843, Green F1: 0.9370, Red F1: 0.3008, a: 0.080, b: 0.070
# Accuracy: 0.8514, Green F1: 0.9128, Red F1: 0.4966, a: 0.040, b: 0.075
# Accuracy: 0.8763, Green F1: 0.9294, Red F1: 0.5000, a: 0.045, b: 0.075
# Accuracy: 0.8904, Green F1: 0.9387, Red F1: 0.4858, a: 0.050, b: 0.075
# Accuracy: 0.8931, Green F1: 0.9408, Red F1: 0.4498, a: 0.055, b: 0.075
# Accuracy: 0.8911, Green F1: 0.9403, Red F1: 0.3817, a: 0.060, b: 0.075
# Accuracy: 0.8884, Green F1: 0.9389, Red F1: 0.3516, a: 0.065, b: 0.075
# Accuracy: 0.8870, Green F1: 0.9383, Red F1: 0.3280, a: 0.070, b: 0.075
# Accuracy: 0.8850, Green F1: 0.9373, Red F1: 0.3020, a: 0.075, b: 0.075
# Accuracy: 0.8823, Green F1: 0.9360, Red F1: 0.2739, a: 0.080, b: 0.075
# Accuracy: 0.8514, Green F1: 0.9128, Red F1: 0.4966, a: 0.040, b: 0.080
# Accuracy: 0.8756, Green F1: 0.9290, Red F1: 0.4959, a: 0.045, b: 0.080
# Accuracy: 0.8897, Green F1: 0.9383, Red F1: 0.4810, a: 0.050, b: 0.080
# Accuracy: 0.8924, Green F1: 0.9404, Red F1: 0.4444, a: 0.055, b: 0.080
# Accuracy: 0.8904, Green F1: 0.9399, Red F1: 0.3755, a: 0.060, b: 0.080
# Accuracy: 0.8877, Green F1: 0.9386, Red F1: 0.3451, a: 0.065, b: 0.080
# Accuracy: 0.8863, Green F1: 0.9380, Red F1: 0.3213, a: 0.070, b: 0.080
# Accuracy: 0.8837, Green F1: 0.9367, Red F1: 0.2881, a: 0.075, b: 0.080
# Accuracy: 0.8803, Green F1: 0.9349, Red F1: 0.2521, a: 0.080, b: 0.080

# %%
classification_reports
# Out:
# {(0.04,
#   0.04): {'g': {'precision': 0.9396195202646815,
#    'recall': 0.8881939014855356,
#    'f1-score': 0.9131832797427653,
#    'support': 1279}, 'r': {'precision': 0.4856115107913669,
#    'recall': 0.6490384615384616,
#    'f1-score': 0.5555555555555556,
#    'support': 208}, 'accuracy': 0.8547410894418291, 'macro avg': {'precision': 0.7126155155280243,
#    'recall': 0.7686161815119985,
#    'f1-score': 0.7343694176491604,
#    'support': 1487}, 'weighted avg': {'precision': 0.8761133561957849,
#    'recall': 0.8547410894418291,
#    'f1-score': 0.8631586888678899,
#    'support': 1487}},
#  (0.045,
#   0.04): {'g': {'precision': 0.9368088467614534,
#    'recall': 0.9272869429241595,
#    'f1-score': 0.9320235756385068,
#    'support': 1279}, 'r': {'precision': 0.579185520361991,
#    'recall': 0.6153846153846154,
#    'f1-score': 0.5967365967365967,
#    'support': 208}, 'accuracy': 0.8836583725622058, 'macro avg': {'precision': 0.7579971835617222,
#    'recall': 0.7713357791543874,
#    'f1-score': 0.7643800861875518,
#    'support': 1487}, 'weighted avg': {'precision': 0.8867848710445144,
#    'recall': 0.8836583725622058,
#    'f1-score': 0.8851239847766391,
#    'support': 1487}},
#  (0.05,
#   0.04): {'g': {'precision': 0.9326186830015314,
#    'recall': 0.9523064894448788,
#    'f1-score': 0.9423597678916827,
#    'support': 1279}, 'r': {'precision': 0.6629834254143646,
#    'recall': 0.5769230769230769,
#    'f1-score': 0.6169665809768639,
#    'support': 208}, 'accuracy': 0.8997982515131137, 'macro avg': {'precision': 0.797801054207948,
#    'recall': 0.7646147831839778,
#    'f1-score': 0.7796631744342732,
#    'support': 1487}, 'weighted avg': {'precision': 0.8949023860424657,
#    'recall': 0.8997982515131137,
#    'f1-score': 0.8968441102734699,
#    'support': 1487}},
#  (0.055,
#   0.04): {'g': {'precision': 0.9304610733182161,
#    'recall': 0.962470680218921,
#    'f1-score': 0.9461952344350499,
#    'support': 1279}, 'r': {'precision': 0.7073170731707317,
#    'recall': 0.5576923076923077,
#    'f1-score': 0.6236559139784946,
#    'support': 208}, 'accuracy': 0.9058507061197041, 'macro avg': {'precision': 0.8188890732444739,
#    'recall': 0.7600814939556144,
#    'f1-score': 0.7849255742067722,
#    'support': 1487}, 'weighted avg': {'precision': 0.8992479246762007,
#    'recall': 0.9058507061197041,
#    'f1-score': 0.9010787726630503,
#    'support': 1487}},
#  (0.06,
#   0.04): {'g': {'precision': 0.9281974569932685,
#    'recall': 0.9702892885066459,
#    'f1-score': 0.9487767584097859,
#    'support': 1279}, 'r': {'precision': 0.7466666666666667,
#    'recall': 0.5384615384615384,
#    'f1-score': 0.6256983240223464,
#    'support': 208}, 'accuracy': 0.9098856758574311, 'macro avg': {'precision': 0.8374320618299675,
#    'recall': 0.7543754134840921,
#    'f1-score': 0.7872375412160662,
#    'support': 1487}, 'weighted avg': {'precision': 0.9028051204849072,
#    'recall': 0.9098856758574311,
#    'f1-score': 0.9035848859467144,
#    'support': 1487}},
#  (0.065,
#   0.04): {'g': {'precision': 0.9261194029850747,
#    'recall': 0.9702892885066459,
#    'f1-score': 0.9476899579992364,
#    'support': 1279}, 'r': {'precision': 0.7414965986394558,
#    'recall': 0.5240384615384616,
#    'f1-score': 0.6140845070422535,
#    'support': 208}, 'accuracy': 0.9078681909885676, 'macro avg': {'precision': 0.8338080008122652,
#    'recall': 0.7471638750225538,
#    'f1-score': 0.780887232520745,
#    'support': 1487}, 'weighted avg': {'precision': 0.9002945587995408,
#    'recall': 0.9078681909885676,
#    'f1-score': 0.9010255775022273,
#    'support': 1487}},
#  (0.07,
#   0.04): {'g': {'precision': 0.924795234549516,
#    'recall': 0.9710711493354183,
#    'f1-score': 0.9473684210526315,
#    'support': 1279}, 'r': {'precision': 0.7430555555555556,
#    'recall': 0.5144230769230769,
#    'f1-score': 0.6079545454545454,
#    'support': 208}, 'accuracy': 0.9071956960322798, 'macro avg': {'precision': 0.8339253950525358,
#    'recall': 0.7427471131292476,
#    'f1-score': 0.7776614832535884,
#    'support': 1487}, 'weighted avg': {'precision': 0.8993736789135081,
#    'recall': 0.9071956960322798,
#    'f1-score': 0.8998915642103975,
#    'support': 1487}},
#  (0.075,
#   0.04): {'g': {'precision': 0.9241635687732342,
#    'recall': 0.9718530101641908,
#    'f1-score': 0.9474085365853658,
#    'support': 1279}, 'r': {'precision': 0.7464788732394366,
#    'recall': 0.5096153846153846,
#    'f1-score': 0.6057142857142858,
#    'support': 208}, 'accuracy': 0.9071956960322798, 'macro avg': {'precision': 0.8353212210063354,
#    'recall': 0.7407341973897876,
#    'f1-score': 0.7765614111498258,
#    'support': 1487}, 'weighted avg': {'precision': 0.8993092199695826,
#    'recall': 0.9071956960322798,
#    'f1-score': 0.8996127032422693,
#    'support': 1487}},
#  (0.08,
#   0.04): {'g': {'precision': 0.9234769687964339,
#    'recall': 0.9718530101641908,
#    'f1-score': 0.947047619047619,
#    'support': 1279}, 'r': {'precision': 0.7446808510638298,
#    'recall': 0.5048076923076923,
#    'f1-score': 0.6017191977077364,
#    'support': 208}, 'accuracy': 0.9065232010759919, 'macro avg': {'precision': 0.8340789099301318,
#    'recall': 0.7383303512359416,
#    'f1-score': 0.7743834083776777,
#    'support': 1487}, 'weighted avg': {'precision': 0.8984671554215977,
#    'recall': 0.9065232010759919,
#    'f1-score': 0.898743441751926,
#    'support': 1487}},
#  (0.04,
#   0.045): {'g': {'precision': 0.9311183144246353,
#    'recall': 0.8983580922595777,
#    'f1-score': 0.9144448865897333,
#    'support': 1279}, 'r': {'precision': 0.48616600790513836,
#    'recall': 0.5913461538461539,
#    'f1-score': 0.5336225596529285,
#    'support': 208}, 'accuracy': 0.855413584398117, 'macro avg': {'precision': 0.7086421611648869,
#    'recall': 0.7448521230528657,
#    'f1-score': 0.724033723121331,
#    'support': 1487}, 'weighted avg': {'precision': 0.8688788525846519,
#    'recall': 0.855413584398117,
#    'f1-score': 0.8611758590155199,
#    'support': 1487}},
#  (0.045,
#   0.045): {'g': {'precision': 0.9259830377794911,
#    'recall': 0.9390148553557467,
#    'f1-score': 0.9324534161490683,
#    'support': 1279}, 'r': {'precision': 0.5894736842105263,
#    'recall': 0.5384615384615384,
#    'f1-score': 0.5628140703517588,
#    'support': 208}, 'accuracy': 0.882985877605918, 'macro avg': {'precision': 0.7577283609950087,
#    'recall': 0.7387381969086426,
#    'f1-score': 0.7476337432504135,
#    'support': 1487}, 'weighted avg': {'precision': 0.8789124624315793,
#    'recall': 0.882985877605918,
#    'f1-score': 0.8807486522446699,
#    'support': 1487}},
#  (0.05,
#   0.045): {'g': {'precision': 0.9203869047619048,
#    'recall': 0.9671618451915559,
#    'f1-score': 0.9431948150972169,
#    'support': 1279}, 'r': {'precision': 0.7062937062937062,
#    'recall': 0.4855769230769231,
#    'f1-score': 0.5754985754985755,
#    'support': 208}, 'accuracy': 0.8997982515131137, 'macro avg': {'precision': 0.8133403055278055,
#    'recall': 0.7263693841342395,
#    'f1-score': 0.7593466952978962,
#    'support': 1487}, 'weighted avg': {'precision': 0.8904397727636632,
#    'recall': 0.8997982515131137,
#    'f1-score': 0.8917618508493909,
#    'support': 1487}},
#  (0.055,
#   0.045): {'g': {'precision': 0.9159356725146199,
#    'recall': 0.9796716184519155,
#    'f1-score': 0.9467321496033245,
#    'support': 1279}, 'r': {'precision': 0.7815126050420168,
#    'recall': 0.44711538461538464,
#    'f1-score': 0.5688073394495413,
#    'support': 208}, 'accuracy': 0.9051782111634162, 'macro avg': {'precision': 0.8487241387783184,
#    'recall': 0.7133935015336501,
#    'f1-score': 0.7577697445264329,
#    'support': 1487}, 'weighted avg': {'precision': 0.8971327148587347,
#    'recall': 0.9051782111634162,
#    'f1-score': 0.8938684236369581,
#    'support': 1487}},
#  (0.06,
#   0.045): {'g': {'precision': 0.9106628242074928,
#    'recall': 0.9882720875684128,
#    'f1-score': 0.9478815148106486,
#    'support': 1279}, 'r': {'precision': 0.8484848484848485,
#    'recall': 0.40384615384615385,
#    'f1-score': 0.5472312703583062,
#    'support': 208}, 'accuracy': 0.9065232010759919, 'macro avg': {'precision': 0.8795738363461707,
#    'recall': 0.6960591207072833,
#    'f1-score': 0.7475563925844775,
#    'support': 1487}, 'weighted avg': {'precision': 0.9019654341938343,
#    'recall': 0.9065232010759919,
#    'f1-score': 0.8918389789356741,
#    'support': 1487}},
#  (0.065,
#   0.045): {'g': {'precision': 0.9086987778576564,
#    'recall': 0.9882720875684128,
#    'f1-score': 0.9468164794007492,
#    'support': 1279}, 'r': {'precision': 0.84375,
#    'recall': 0.3894230769230769,
#    'f1-score': 0.5328947368421053,
#    'support': 208}, 'accuracy': 0.9045057162071285, 'macro avg': {'precision': 0.8762243889288281,
#    'recall': 0.6888475822457448,
#    'f1-score': 0.7398556081214273,
#    'support': 1487}, 'weighted avg': {'precision': 0.8996138109481793,
#    'recall': 0.9045057162071285,
#    'f1-score': 0.8889175402936895,
#    'support': 1487}},
#  (0.07,
#   0.045): {'g': {'precision': 0.9075268817204301,
#    'recall': 0.9898358092259578,
#    'f1-score': 0.9468960359012715,
#    'support': 1279}, 'r': {'precision': 0.8586956521739131,
#    'recall': 0.3798076923076923,
#    'f1-score': 0.5266666666666666,
#    'support': 208}, 'accuracy': 0.9045057162071285, 'macro avg': {'precision': 0.8831112669471716,
#    'recall': 0.684821750766825,
#    'f1-score': 0.736781351283969,
#    'support': 1487}, 'weighted avg': {'precision': 0.900696420559922,
#    'recall': 0.9045057162071285,
#    'f1-score': 0.8881147925920598,
#    'support': 1487}},
#  (0.075,
#   0.045): {'g': {'precision': 0.9056468906361687,
#    'recall': 0.9906176700547302,
#    'f1-score': 0.9462285287528005,
#    'support': 1279}, 'r': {'precision': 0.8636363636363636,
#    'recall': 0.36538461538461536,
#    'f1-score': 0.5135135135135135,
#    'support': 208}, 'accuracy': 0.9031607262945528, 'macro avg': {'precision': 0.8846416271362662,
#    'recall': 0.6780011427196728,
#    'f1-score': 0.7298710211331569,
#    'support': 1487}, 'weighted avg': {'precision': 0.8997705021923493,
#    'recall': 0.9031607262945528,
#    'f1-score': 0.8857008063790469,
#    'support': 1487}},
#  (0.08,
#   0.045): {'g': {'precision': 0.9043540328336902,
#    'recall': 0.9906176700547302,
#    'f1-score': 0.9455223880597015,
#    'support': 1279}, 'r': {'precision': 0.8604651162790697,
#    'recall': 0.3557692307692308,
#    'f1-score': 0.5034013605442177,
#    'support': 208}, 'accuracy': 0.9018157363819771, 'macro avg': {'precision': 0.88240957455638,
#    'recall': 0.6731934504119805,
#    'f1-score': 0.7244618743019595,
#    'support': 1487}, 'weighted avg': {'precision': 0.898214897229547,
#    'recall': 0.9018157363819771,
#    'f1-score': 0.883678962556527,
#    'support': 1487}},
#  (0.04,
#   0.05): {'g': {'precision': 0.9283990345937249,
#    'recall': 0.9022673964034402,
#    'f1-score': 0.915146708961142,
#    'support': 1279}, 'r': {'precision': 0.48770491803278687,
#    'recall': 0.5721153846153846,
#    'f1-score': 0.5265486725663716,
#    'support': 208}, 'accuracy': 0.8560860793544048, 'macro avg': {'precision': 0.7080519763132559,
#    'recall': 0.7371913905094124,
#    'f1-score': 0.7208476907637569,
#    'support': 1487}, 'weighted avg': {'precision': 0.866755203897911,
#    'recall': 0.8560860793544048,
#    'f1-score': 0.8607900233053839,
#    'support': 1487}},
#  (0.045,
#   0.05): {'g': {'precision': 0.9221374045801527,
#    'recall': 0.944487881157154,
#    'f1-score': 0.933178833526458,
#    'support': 1279}, 'r': {'precision': 0.5988700564971752,
#    'recall': 0.5096153846153846,
#    'f1-score': 0.5506493506493506,
#    'support': 208}, 'accuracy': 0.8836583725622058, 'macro avg': {'precision': 0.7605037305386639,
#    'recall': 0.7270516328862693,
#    'f1-score': 0.7419140920879044,
#    'support': 1487}, 'weighted avg': {'precision': 0.8769191070675372,
#    'recall': 0.8836583725622058,
#    'f1-score': 0.8796710107702789,
#    'support': 1487}},
#  (0.05,
#   0.05): {'g': {'precision': 0.9160530191458026,
#    'recall': 0.9726348709929633,
#    'f1-score': 0.9434963974213121,
#    'support': 1279}, 'r': {'precision': 0.7286821705426356,
#    'recall': 0.4519230769230769,
#    'f1-score': 0.5578635014836796,
#    'support': 208}, 'accuracy': 0.8997982515131137, 'macro avg': {'precision': 0.8223675948442191,
#    'recall': 0.7122789739580201,
#    'f1-score': 0.7506799494524958,
#    'support': 1487}, 'weighted avg': {'precision': 0.8898437814124748,
#    'recall': 0.8997982515131137,
#    'f1-score': 0.8895544725019929,
#    'support': 1487}},
#  (0.055,
#   0.05): {'g': {'precision': 0.9117221418234442,
#    'recall': 0.9851446442533229,
#    'f1-score': 0.9470124013528749,
#    'support': 1279}, 'r': {'precision': 0.819047619047619,
#    'recall': 0.41346153846153844,
#    'f1-score': 0.5495207667731629,
#    'support': 208}, 'accuracy': 0.9051782111634162, 'macro avg': {'precision': 0.8653848804355316,
#    'recall': 0.6993030913574307,
#    'f1-score': 0.7482665840630189,
#    'support': 1487}, 'weighted avg': {'precision': 0.8987589268016745,
#    'recall': 0.9051782111634162,
#    'f1-score': 0.8914116885132111,
#    'support': 1487}},
#  (0.06,
#   0.05): {'g': {'precision': 0.905982905982906,
#    'recall': 0.9945269741985927,
#    'f1-score': 0.9481923220275811,
#    'support': 1279}, 'r': {'precision': 0.9156626506024096,
#    'recall': 0.36538461538461536,
#    'f1-score': 0.5223367697594502,
#    'support': 208}, 'accuracy': 0.9065232010759919, 'macro avg': {'precision': 0.9108227782926578,
#    'recall': 0.6799557947916041,
#    'f1-score': 0.7352645458935156,
#    'support': 1487}, 'weighted avg': {'precision': 0.9073368985053382,
#    'recall': 0.9065232010759919,
#    'f1-score': 0.8886240941380241,
#    'support': 1487}},
#  (0.065,
#   0.05): {'g': {'precision': 0.9041193181818182,
#    'recall': 0.9953088350273651,
#    'f1-score': 0.9475251209527354,
#    'support': 1279}, 'r': {'precision': 0.9240506329113924,
#    'recall': 0.35096153846153844,
#    'f1-score': 0.5087108013937283,
#    'support': 208}, 'accuracy': 0.9051782111634162, 'macro avg': {'precision': 0.9140849755466054,
#    'recall': 0.6731351867444517,
#    'f1-score': 0.7281179611732318,
#    'support': 1487}, 'weighted avg': {'precision': 0.9069072895764057,
#    'recall': 0.9051782111634162,
#    'f1-score': 0.8861442342894715,
#    'support': 1487}},
#  (0.07,
#   0.05): {'g': {'precision': 0.9016973125884017,
#    'recall': 0.99687255668491,
#    'f1-score': 0.9468993687337541,
#    'support': 1279}, 'r': {'precision': 0.9452054794520548,
#    'recall': 0.3317307692307692,
#    'f1-score': 0.4911032028469751,
#    'support': 208}, 'accuracy': 0.9038332212508406, 'macro avg': {'precision': 0.9234513960202282,
#    'recall': 0.6643016629578397,
#    'f1-score': 0.7190012857903646,
#    'support': 1487}, 'weighted avg': {'precision': 0.907783189325214,
#    'recall': 0.9038332212508406,
#    'f1-score': 0.8831430792216828,
#    'support': 1487}},
#  (0.075,
#   0.05): {'g': {'precision': 0.8998589562764457,
#    'recall': 0.9976544175136826,
#    'f1-score': 0.946236559139785,
#    'support': 1279}, 'r': {'precision': 0.9565217391304348,
#    'recall': 0.3173076923076923,
#    'f1-score': 0.47653429602888087,
#    'support': 208}, 'accuracy': 0.902488231338265, 'macro avg': {'precision': 0.9281903477034403,
#    'recall': 0.6574810549106874,
#    'f1-score': 0.711385427584333,
#    'support': 1487}, 'weighted avg': {'precision': 0.9077848868975821,
#    'recall': 0.902488231338265,
#    'f1-score': 0.8805350993367802,
#    'support': 1487}},
#  (0.08,
#   0.05): {'g': {'precision': 0.8985915492957747,
#    'recall': 0.9976544175136826,
#    'f1-score': 0.9455353834753613,
#    'support': 1279}, 'r': {'precision': 0.9552238805970149,
#    'recall': 0.3076923076923077,
#    'f1-score': 0.4654545454545455,
#    'support': 208}, 'accuracy': 0.9011432414256894, 'macro avg': {'precision': 0.9269077149463948,
#    'recall': 0.6526733626029951,
#    'f1-score': 0.7054949644649534,
#    'support': 1487}, 'weighted avg': {'precision': 0.906513220385659,
#    'recall': 0.9011432414256894,
#    'f1-score': 0.8783821795020393,
#    'support': 1487}},
#  (0.04,
#   0.055): {'g': {'precision': 0.9255404323458767,
#    'recall': 0.9038311180609852,
#    'f1-score': 0.9145569620253164,
#    'support': 1279}, 'r': {'precision': 0.4831932773109244,
#    'recall': 0.5528846153846154,
#    'f1-score': 0.5156950672645739,
#    'support': 208}, 'accuracy': 0.8547410894418291, 'macro avg': {'precision': 0.7043668548284006,
#    'recall': 0.7283578667228003,
#    'f1-score': 0.7151260146449452,
#    'support': 1487}, 'weighted avg': {'precision': 0.8636653763625074,
#    'recall': 0.8547410894418291,
#    'f1-score': 0.8587645786290592,
#    'support': 1487}},
#  (0.045,
#   0.055): {'g': {'precision': 0.9180576631259484,
#    'recall': 0.946051602814699,
#    'f1-score': 0.9318444358875627,
#    'support': 1279}, 'r': {'precision': 0.591715976331361,
#    'recall': 0.4807692307692308,
#    'f1-score': 0.5305039787798409,
#    'support': 208}, 'accuracy': 0.8809683927370545, 'macro avg': {'precision': 0.7548868197286547,
#    'recall': 0.7134104167919649,
#    'f1-score': 0.7311742073337018,
#    'support': 1487}, 'weighted avg': {'precision': 0.8724093303396174,
#    'recall': 0.8809683927370545,
#    'f1-score': 0.8757053537904503,
#    'support': 1487}},
#  (0.05,
#   0.055): {'g': {'precision': 0.9108187134502924,
#    'recall': 0.9741985926505082,
#    'f1-score': 0.9414431431809597,
#    'support': 1279}, 'r': {'precision': 0.7226890756302521,
#    'recall': 0.41346153846153844,
#    'f1-score': 0.5259938837920489,
#    'support': 208}, 'accuracy': 0.8957632817753867, 'macro avg': {'precision': 0.8167538945402723,
#    'recall': 0.6938300655560233,
#    'f1-score': 0.7337185134865043,
#    'support': 1487}, 'weighted avg': {'precision': 0.884503337077348,
#    'recall': 0.8957632817753867,
#    'f1-score': 0.883330536622188,
#    'support': 1487}},
#  (0.055,
#   0.055): {'g': {'precision': 0.9053084648493543,
#    'recall': 0.9867083659108679,
#    'f1-score': 0.9442573887018332,
#    'support': 1279}, 'r': {'precision': 0.8172043010752689,
#    'recall': 0.36538461538461536,
#    'f1-score': 0.5049833887043189,
#    'support': 208}, 'accuracy': 0.8997982515131137, 'macro avg': {'precision': 0.8612563829623117,
#    'recall': 0.6760464906477416,
#    'f1-score': 0.724620388703076,
#    'support': 1487}, 'weighted avg': {'precision': 0.8929845468500202,
#    'recall': 0.8997982515131137,
#    'f1-score': 0.882812202421078,
#    'support': 1487}},
#  (0.06,
#   0.055): {'g': {'precision': 0.8984485190409027,
#    'recall': 0.9960906958561376,
#    'f1-score': 0.9447534297367446,
#    'support': 1279}, 'r': {'precision': 0.927536231884058,
#    'recall': 0.3076923076923077,
#    'f1-score': 0.4620938628158845,
#    'support': 208}, 'accuracy': 0.8997982515131137, 'macro avg': {'precision': 0.9129923754624804,
#    'recall': 0.6518915017742226,
#    'f1-score': 0.7034236462763146,
#    'support': 1487}, 'weighted avg': {'precision': 0.9025172777977126,
#    'recall': 0.8997982515131137,
#    'f1-score': 0.8772395158702087,
#    'support': 1487}},
#  (0.065,
#   0.055): {'g': {'precision': 0.8966244725738397,
#    'recall': 0.99687255668491,
#    'f1-score': 0.9440947797112181,
#    'support': 1279}, 'r': {'precision': 0.9384615384615385,
#    'recall': 0.2932692307692308,
#    'f1-score': 0.44688644688644685,
#    'support': 208}, 'accuracy': 0.898453261600538, 'macro avg': {'precision': 0.9175430055176891,
#    'recall': 0.6450708937270704,
#    'f1-score': 0.6954906132988325,
#    'support': 1487}, 'weighted avg': {'precision': 0.9024765974592743,
#    'recall': 0.898453261600538,
#    'f1-score': 0.8745457997330389,
#    'support': 1487}},
#  (0.07,
#   0.055): {'g': {'precision': 0.8942577030812325,
#    'recall': 0.9984362783424551,
#    'f1-score': 0.9434798670114518,
#    'support': 1279}, 'r': {'precision': 0.9661016949152542,
#    'recall': 0.27403846153846156,
#    'f1-score': 0.4269662921348315,
#    'support': 208}, 'accuracy': 0.8971082716879624, 'macro avg': {'precision': 0.9301796989982434,
#    'recall': 0.6362373699404583,
#    'f1-score': 0.6852230795731417,
#    'support': 1487}, 'weighted avg': {'precision': 0.904307165288009,
#    'recall': 0.8971082716879624,
#    'f1-score': 0.8712304900280375,
#    'support': 1487}},
#  (0.075,
#   0.055): {'g': {'precision': 0.8924581005586593,
#    'recall': 0.9992181391712275,
#    'f1-score': 0.9428255256362965,
#    'support': 1279}, 'r': {'precision': 0.9818181818181818,
#    'recall': 0.25961538461538464,
#    'f1-score': 0.41064638783269963,
#    'support': 208}, 'accuracy': 0.8957632817753867, 'macro avg': {'precision': 0.9371381411884205,
#    'recall': 0.6294167618933061,
#    'f1-score': 0.676735956734498,
#    'support': 1487}, 'weighted avg': {'precision': 0.9049576949782832,
#    'recall': 0.8957632817753867,
#    'f1-score': 0.8683848661452755,
#    'support': 1487}},
#  (0.08,
#   0.055): {'g': {'precision': 0.891213389121339,
#    'recall': 0.9992181391712275,
#    'f1-score': 0.9421304828603022,
#    'support': 1279}, 'r': {'precision': 0.9811320754716981,
#    'recall': 0.25,
#    'f1-score': 0.39846743295019155,
#    'support': 208}, 'accuracy': 0.8944182918628111, 'macro avg': {'precision': 0.9361727322965185,
#    'recall': 0.6246090695856137,
#    'f1-score': 0.6702989579052469,
#    'support': 1487}, 'weighted avg': {'precision': 0.9037911206350407,
#    'recall': 0.8944182918628111,
#    'f1-score': 0.8660834657915041,
#    'support': 1487}},
#  (0.04,
#   0.06): {'g': {'precision': 0.922585794094174,
#    'recall': 0.9038311180609852,
#    'f1-score': 0.9131121642969985,
#    'support': 1279}, 'r': {'precision': 0.47435897435897434,
#    'recall': 0.5336538461538461,
#    'f1-score': 0.502262443438914,
#    'support': 208}, 'accuracy': 0.8520511096166778, 'macro avg': {'precision': 0.6984723842265741,
#    'recall': 0.7187424821074156,
#    'f1-score': 0.7076873038679563,
#    'support': 1487}, 'weighted avg': {'precision': 0.8598882967808442,
#    'recall': 0.8520511096166778,
#    'f1-score': 0.8556429363625792,
#    'support': 1487}},
#  (0.045,
#   0.06): {'g': {'precision': 0.9152798789712556,
#    'recall': 0.946051602814699,
#    'f1-score': 0.93041138023837,
#    'support': 1279}, 'r': {'precision': 0.5818181818181818,
#    'recall': 0.46153846153846156,
#    'f1-score': 0.514745308310992,
#    'support': 208}, 'accuracy': 0.8782784129119031, 'macro avg': {'precision': 0.7485490303947187,
#    'recall': 0.7037950321765802,
#    'f1-score': 0.7225783442746809,
#    'support': 1487}, 'weighted avg': {'precision': 0.8686356066055264,
#    'recall': 0.8782784129119031,
#    'f1-score': 0.8722684461691739,
#    'support': 1487}},
#  (0.05,
#   0.06): {'g': {'precision': 0.9081632653061225,
#    'recall': 0.9741985926505082,
#    'f1-score': 0.9400226329686912,
#    'support': 1279}, 'r': {'precision': 0.7130434782608696,
#    'recall': 0.3942307692307692,
#    'f1-score': 0.5077399380804953,
#    'support': 208}, 'accuracy': 0.8930733019502354, 'macro avg': {'precision': 0.810603371783496,
#    'recall': 0.6842146809406388,
#    'f1-score': 0.7238812855245933,
#    'support': 1487}, 'weighted avg': {'precision': 0.8808701141928658,
#    'recall': 0.8930733019502354,
#    'f1-score': 0.8795553831121042,
#    'support': 1487}},
#  (0.055,
#   0.06): {'g': {'precision': 0.9027181688125894,
#    'recall': 0.9867083659108679,
#    'f1-score': 0.942846469929025,
#    'support': 1279}, 'r': {'precision': 0.8089887640449438,
#    'recall': 0.34615384615384615,
#    'f1-score': 0.4848484848484849,
#    'support': 208}, 'accuracy': 0.8971082716879624, 'macro avg': {'precision': 0.8558534664287666,
#    'recall': 0.666431106032357,
#    'f1-score': 0.713847477388755,
#    'support': 1487}, 'weighted avg': {'precision': 0.8896073980044722,
#    'recall': 0.8971082716879624,
#    'f1-score': 0.8787821922580416,
#    'support': 1487}},
#  (0.06,
#   0.06): {'g': {'precision': 0.8952916373858046,
#    'recall': 0.9960906958561376,
#    'f1-score': 0.9430051813471504,
#    'support': 1279}, 'r': {'precision': 0.921875,
#    'recall': 0.28365384615384615,
#    'f1-score': 0.43382352941176466,
#    'support': 208}, 'accuracy': 0.8964357767316745, 'macro avg': {'precision': 0.9085833186929023,
#    'recall': 0.6398722710049919,
#    'f1-score': 0.6884143553794575,
#    'support': 1487}, 'weighted avg': {'precision': 0.8990100902598818,
#    'recall': 0.8964357767316745,
#    'f1-score': 0.8717813860528933,
#    'support': 1487}},
#  (0.065,
#   0.06): {'g': {'precision': 0.8934828311142257,
#    'recall': 0.99687255668491,
#    'f1-score': 0.9423503325942351,
#    'support': 1279}, 'r': {'precision': 0.9333333333333333,
#    'recall': 0.2692307692307692,
#    'f1-score': 0.417910447761194,
#    'support': 208}, 'accuracy': 0.8950907868190988, 'macro avg': {'precision': 0.9134080822237796,
#    'recall': 0.6330516629578397,
#    'f1-score': 0.6801303901777145,
#    'support': 1487}, 'weighted avg': {'precision': 0.8990570775577861,
#    'recall': 0.8950907868190988,
#    'f1-score': 0.868992231689546,
#    'support': 1487}},
#  (0.07,
#   0.06): {'g': {'precision': 0.8911374738311235,
#    'recall': 0.9984362783424551,
#    'f1-score': 0.9417404129793511,
#    'support': 1279}, 'r': {'precision': 0.9629629629629629,
#    'recall': 0.25,
#    'f1-score': 0.39694656488549623,
#    'support': 208}, 'accuracy': 0.8937457969065232, 'macro avg': {'precision': 0.9270502183970433,
#    'recall': 0.6242181391712276,
#    'f1-score': 0.6693434889324237,
#    'support': 1487}, 'weighted avg': {'precision': 0.9011843478993297,
#    'recall': 0.8937457969065232,
#    'f1-score': 0.8655352210469223,
#    'support': 1487}},
#  (0.075,
#   0.06): {'g': {'precision': 0.8893528183716075,
#    'recall': 0.9992181391712275,
#    'f1-score': 0.9410898379970545,
#    'support': 1279}, 'r': {'precision': 0.98,
#    'recall': 0.23557692307692307,
#    'f1-score': 0.3798449612403101,
#    'support': 208}, 'accuracy': 0.8924008069939475, 'macro avg': {'precision': 0.9346764091858037,
#    'recall': 0.6173975311240752,
#    'f1-score': 0.6604673996186823,
#    'support': 1487}, 'weighted avg': {'precision': 0.902032451040542,
#    'recall': 0.8924008069939475,
#    'f1-score': 0.8625834934339053,
#    'support': 1487}},
#  (0.08,
#   0.06): {'g': {'precision': 0.8881167477414872,
#    'recall': 0.9992181391712275,
#    'f1-score': 0.9403973509933775,
#    'support': 1279}, 'r': {'precision': 0.9791666666666666,
#    'recall': 0.22596153846153846,
#    'f1-score': 0.3671875,
#    'support': 208}, 'accuracy': 0.8910558170813719, 'macro avg': {'precision': 0.9336417072040769,
#    'recall': 0.612589838816383,
#    'f1-score': 0.6537924254966887,
#    'support': 1487}, 'weighted avg': {'precision': 0.9008527148809878,
#    'recall': 0.8910558170813719,
#    'f1-score': 0.8602173583863685,
#    'support': 1487}},
#  (0.04,
#   0.065): {'g': {'precision': 0.9218500797448166,
#    'recall': 0.9038311180609852,
#    'f1-score': 0.912751677852349,
#    'support': 1279}, 'r': {'precision': 0.4721030042918455,
#    'recall': 0.5288461538461539,
#    'f1-score': 0.49886621315192736,
#    'support': 208}, 'accuracy': 0.85137861466039, 'macro avg': {'precision': 0.696976542018331,
#    'recall': 0.7163386359535695,
#    'f1-score': 0.7058089455021381,
#    'support': 1487}, 'weighted avg': {'precision': 0.8589399306565731,
#    'recall': 0.85137861466039,
#    'f1-score': 0.8548578132540386,
#    'support': 1487}},
#  (0.045,
#   0.065): {'g': {'precision': 0.9145880574452003,
#    'recall': 0.946051602814699,
#    'f1-score': 0.930053804765565,
#    'support': 1279}, 'r': {'precision': 0.5792682926829268,
#    'recall': 0.4567307692307692,
#    'f1-score': 0.5107526881720429,
#    'support': 208}, 'accuracy': 0.8776059179556154, 'macro avg': {'precision': 0.7469281750640635,
#    'recall': 0.7013911860227341,
#    'f1-score': 0.7204032464688039,
#    'support': 1487}, 'weighted avg': {'precision': 0.8676838805315803,
#    'recall': 0.8776059179556154,
#    'f1-score': 0.8714024044619654,
#    'support': 1487}},
#  (0.05,
#   0.065): {'g': {'precision': 0.9075018208302986,
#    'recall': 0.9741985926505082,
#    'f1-score': 0.9396681749622926,
#    'support': 1279}, 'r': {'precision': 0.7105263157894737,
#    'recall': 0.3894230769230769,
#    'f1-score': 0.5031055900621119,
#    'support': 208}, 'accuracy': 0.8924008069939475, 'macro avg': {'precision': 0.8090140683098861,
#    'recall': 0.6818108347867926,
#    'f1-score': 0.7213868825122023,
#    'support': 1487}, 'weighted avg': {'precision': 0.8799490938306406,
#    'recall': 0.8924008069939475,
#    'f1-score': 0.8786022585808282,
#    'support': 1487}},
#  (0.055,
#   0.065): {'g': {'precision': 0.902072909220872,
#    'recall': 0.9867083659108679,
#    'f1-score': 0.9424943988050783,
#    'support': 1279}, 'r': {'precision': 0.8068181818181818,
#    'recall': 0.34134615384615385,
#    'f1-score': 0.47972972972972977,
#    'support': 208}, 'accuracy': 0.8964357767316745, 'macro avg': {'precision': 0.8544455455195269,
#    'recall': 0.6640272598785109,
#    'f1-score': 0.711112064267404,
#    'support': 1487}, 'weighted avg': {'precision': 0.8887487778827687,
#    'recall': 0.8964357767316745,
#    'f1-score': 0.8777633623775917,
#    'support': 1487}},
#  (0.06,
#   0.065): {'g': {'precision': 0.8934081346423562,
#    'recall': 0.9960906958561376,
#    'f1-score': 0.9419593345656192,
#    'support': 1279}, 'r': {'precision': 0.9180327868852459,
#    'recall': 0.2692307692307692,
#    'f1-score': 0.4163568773234201,
#    'support': 208}, 'accuracy': 0.8944182918628111, 'macro avg': {'precision': 0.9057204607638011,
#    'recall': 0.6326607325434535,
#    'f1-score': 0.6791581059445196,
#    'support': 1487}, 'weighted avg': {'precision': 0.8968526051645627,
#    'recall': 0.8944182918628111,
#    'f1-score': 0.8684386142519828,
#    'support': 1487}},
#  (0.065,
#   0.065): {'g': {'precision': 0.8916083916083916,
#    'recall': 0.99687255668491,
#    'f1-score': 0.9413067552602435,
#    'support': 1279}, 'r': {'precision': 0.9298245614035088,
#    'recall': 0.2548076923076923,
#    'f1-score': 0.39999999999999997,
#    'support': 208}, 'accuracy': 0.8930733019502354, 'macro avg': {'precision': 0.9107164765059501,
#    'recall': 0.6258401244963012,
#    'f1-score': 0.6706533776301218,
#    'support': 1487}, 'weighted avg': {'precision': 0.8969540293470495,
#    'recall': 0.8930733019502354,
#    'f1-score': 0.8655893342150984,
#    'support': 1487}},
#  (0.07,
#   0.065): {'g': {'precision': 0.8892757660167131,
#    'recall': 0.9984362783424551,
#    'f1-score': 0.9406998158379374,
#    'support': 1279}, 'r': {'precision': 0.9607843137254902,
#    'recall': 0.23557692307692307,
#    'f1-score': 0.3783783783783784,
#    'support': 208}, 'accuracy': 0.8917283120376597, 'macro avg': {'precision': 0.9250300398711017,
#    'recall': 0.617006600709689,
#    'f1-score': 0.6595390971081578,
#    'support': 1487}, 'weighted avg': {'precision': 0.899278306651162,
#    'recall': 0.8917283120376597,
#    'f1-score': 0.8620428830930899,
#    'support': 1487}},
#  (0.075,
#   0.065): {'g': {'precision': 0.8875,
#    'recall': 0.9992181391712275,
#    'f1-score': 0.9400514895182052,
#    'support': 1279}, 'r': {'precision': 0.9787234042553191,
#    'recall': 0.22115384615384615,
#    'f1-score': 0.3607843137254902,
#    'support': 208}, 'accuracy': 0.8903833221250841, 'macro avg': {'precision': 0.9331117021276596,
#    'recall': 0.6101859926625368,
#    'f1-score': 0.6504179016218476,
#    'support': 1487}, 'weighted avg': {'precision': 0.9002602340854784,
#    'recall': 0.8903833221250841,
#    'f1-score': 0.8590242046729565,
#    'support': 1487}},
#  (0.08,
#   0.065): {'g': {'precision': 0.8862690707350902,
#    'recall': 0.9992181391712275,
#    'f1-score': 0.9393605292171996,
#    'support': 1279}, 'r': {'precision': 0.9777777777777777,
#    'recall': 0.21153846153846154,
#    'f1-score': 0.34782608695652173,
#    'support': 208}, 'accuracy': 0.8890383322125084, 'macro avg': {'precision': 0.932023424256434,
#    'recall': 0.6053783003548445,
#    'f1-score': 0.6435933080868607,
#    'support': 1487}, 'weighted avg': {'precision': 0.8990692126751567,
#    'recall': 0.8890383322125084,
#    'f1-score': 0.8566173120079049,
#    'support': 1487}},
#  (0.04,
#   0.07): {'g': {'precision': 0.9211155378486056,
#    'recall': 0.9038311180609852,
#    'f1-score': 0.9123914759273875,
#    'support': 1279}, 'r': {'precision': 0.4698275862068966,
#    'recall': 0.5240384615384616,
#    'f1-score': 0.4954545454545455,
#    'support': 208}, 'accuracy': 0.8507061197041023, 'macro avg': {'precision': 0.6954715620277511,
#    'recall': 0.7139347897997234,
#    'f1-score': 0.7039230106909664,
#    'support': 1487}, 'weighted avg': {'precision': 0.8579898526156026,
#    'recall': 0.8507061197041023,
#    'f1-score': 0.8540707754980995,
#    'support': 1487}},
#  (0.045,
#   0.07): {'g': {'precision': 0.9138972809667674,
#    'recall': 0.946051602814699,
#    'f1-score': 0.9296965040338072,
#    'support': 1279}, 'r': {'precision': 0.5766871165644172,
#    'recall': 0.4519230769230769,
#    'f1-score': 0.5067385444743936,
#    'support': 208}, 'accuracy': 0.8769334229993275, 'macro avg': {'precision': 0.7452921987655923,
#    'recall': 0.698987339868888,
#    'f1-score': 0.7182175242541005,
#    'support': 1487}, 'weighted avg': {'precision': 0.8667286769346968,
#    'recall': 0.8769334229993275,
#    'f1-score': 0.8705335883725038,
#    'support': 1487}},
#  (0.05,
#   0.07): {'g': {'precision': 0.9061818181818182,
#    'recall': 0.9741985926505082,
#    'f1-score': 0.9389600602863601,
#    'support': 1279}, 'r': {'precision': 0.7053571428571429,
#    'recall': 0.3798076923076923,
#    'f1-score': 0.49375,
#    'support': 208}, 'accuracy': 0.8910558170813719, 'macro avg': {'precision': 0.8057694805194806,
#    'recall': 0.6770031424791003,
#    'f1-score': 0.71635503014318,
#    'support': 1487}, 'weighted avg': {'precision': 0.8780906732809893,
#    'recall': 0.8910558170813719,
#    'f1-score': 0.8766845441198754,
#    'support': 1487}},
#  (0.055,
#   0.07): {'g': {'precision': 0.8995010691375623,
#    'recall': 0.9867083659108679,
#    'f1-score': 0.9410887397464578,
#    'support': 1279}, 'r': {'precision': 0.7976190476190477,
#    'recall': 0.32211538461538464,
#    'f1-score': 0.45890410958904115,
#    'support': 208}, 'accuracy': 0.8937457969065232, 'macro avg': {'precision': 0.8485600583783051,
#    'recall': 0.6544118752631263,
#    'f1-score': 0.6999964246677495,
#    'support': 1487}, 'weighted avg': {'precision': 0.8852499188511797,
#    'recall': 0.8937457969065232,
#    'f1-score': 0.8736412595361399,
#    'support': 1487}},
#  (0.06,
#   0.07): {'g': {'precision': 0.8909090909090909,
#    'recall': 0.9960906958561376,
#    'f1-score': 0.9405684754521964,
#    'support': 1279}, 'r': {'precision': 0.9122807017543859,
#    'recall': 0.25,
#    'f1-score': 0.3924528301886792,
#    'support': 208}, 'accuracy': 0.8917283120376597, 'macro avg': {'precision': 0.9015948963317384,
#    'recall': 0.6230453479280689,
#    'f1-score': 0.6665106528204378,
#    'support': 1487}, 'weighted avg': {'precision': 0.893898529413342,
#    'recall': 0.8917283120376597,
#    'f1-score': 0.8638986340165464,
#    'support': 1487}},
#  (0.065,
#   0.07): {'g': {'precision': 0.8885017421602788,
#    'recall': 0.99687255668491,
#    'f1-score': 0.939572586588062,
#    'support': 1279}, 'r': {'precision': 0.9230769230769231,
#    'recall': 0.23076923076923078,
#    'f1-score': 0.36923076923076925,
#    'support': 208}, 'accuracy': 0.8897108271687962, 'macro avg': {'precision': 0.905789332618601,
#    'recall': 0.6138208937270704,
#    'f1-score': 0.6544016779094156,
#    'support': 1487}, 'weighted avg': {'precision': 0.8933380821943487,
#    'recall': 0.8897108271687962,
#    'f1-score': 0.8597937715172369,
#    'support': 1487}},
#  (0.07,
#   0.07): {'g': {'precision': 0.8861901457321305,
#    'recall': 0.9984362783424551,
#    'f1-score': 0.9389705882352941,
#    'support': 1279}, 'r': {'precision': 0.9565217391304348,
#    'recall': 0.21153846153846154,
#    'f1-score': 0.3464566929133859,
#    'support': 208}, 'accuracy': 0.8883658372562205, 'macro avg': {'precision': 0.9213559424312827,
#    'recall': 0.6049873699404583,
#    'f1-score': 0.64271364057434,
#    'support': 1487}, 'weighted avg': {'precision': 0.8960280552323642,
#    'recall': 0.8883658372562205,
#    'f1-score': 0.8560903661593311,
#    'support': 1487}},
#  (0.075,
#   0.07): {'g': {'precision': 0.8838174273858921,
#    'recall': 0.9992181391712275,
#    'f1-score': 0.9379816513761469,
#    'support': 1279}, 'r': {'precision': 0.975609756097561,
#    'recall': 0.19230769230769232,
#    'f1-score': 0.32128514056224905,
#    'support': 208}, 'accuracy': 0.8863483523873571, 'macro avg': {'precision': 0.9297135917417265,
#    'recall': 0.5957629157394599,
#    'f1-score': 0.629633395969198,
#    'support': 1487}, 'weighted avg': {'precision': 0.8966572420274705,
#    'recall': 0.8863483523873571,
#    'f1-score': 0.8517187904149559,
#    'support': 1487}},
#  (0.08,
#   0.07): {'g': {'precision': 0.8819875776397516,
#    'recall': 0.9992181391712275,
#    'f1-score': 0.9369501466275659,
#    'support': 1279}, 'r': {'precision': 0.9736842105263158,
#    'recall': 0.1778846153846154,
#    'f1-score': 0.3008130081300813,
#    'support': 208}, 'accuracy': 0.8843308675184937, 'macro avg': {'precision': 0.9278358940830337,
#    'recall': 0.5885513772779214,
#    'f1-score': 0.6188815773788237,
#    'support': 1487}, 'weighted avg': {'precision': 0.8948140064497082,
#    'recall': 0.8843308675184937,
#    'f1-score': 0.8479679510610044,
#    'support': 1487}},
#  (0.04,
#   0.075): {'g': {'precision': 0.9211783439490446,
#    'recall': 0.9046129788897577,
#    'f1-score': 0.9128205128205129,
#    'support': 1279}, 'r': {'precision': 0.47186147186147187,
#    'recall': 0.5240384615384616,
#    'f1-score': 0.4965831435079727,
#    'support': 208}, 'accuracy': 0.85137861466039, 'macro avg': {'precision': 0.6965199079052582,
#    'recall': 0.7143257202141096,
#    'f1-score': 0.7047018281642428,
#    'support': 1487}, 'weighted avg': {'precision': 0.8583283712562301,
#    'recall': 0.85137861466039,
#    'f1-score': 0.854597666272424,
#    'support': 1487}},
#  (0.045,
#   0.075): {'g': {'precision': 0.9125847776940467,
#    'recall': 0.9468334636434714,
#    'f1-score': 0.9293937068303914,
#    'support': 1279}, 'r': {'precision': 0.575,
#    'recall': 0.4423076923076923,
#    'f1-score': 0.5,
#    'support': 208}, 'accuracy': 0.8762609280430397, 'macro avg': {'precision': 0.7437923888470233,
#    'recall': 0.6945705779755819,
#    'f1-score': 0.7146968534151956,
#    'support': 1487}, 'weighted avg': {'precision': 0.8653637731477374,
#    'recall': 0.8762609280430397,
#    'f1-score': 0.8693305655925155,
#    'support': 1487}},
#  (0.05,
#   0.075): {'g': {'precision': 0.9049346879535559,
#    'recall': 0.9749804534792806,
#    'f1-score': 0.9386526157320286,
#    'support': 1279}, 'r': {'precision': 0.7064220183486238,
#    'recall': 0.3701923076923077,
#    'f1-score': 0.4858044164037855,
#    'support': 208}, 'accuracy': 0.8903833221250841, 'macro avg': {'precision': 0.8056783531510898,
#    'recall': 0.6725863805857941,
#    'f1-score': 0.712228516067907,
#    'support': 1487}, 'weighted avg': {'precision': 0.8771669439872978,
#    'recall': 0.8903833221250841,
#    'f1-score': 0.8753086846894768,
#    'support': 1487}},
#  (0.055,
#   0.075): {'g': {'precision': 0.8982930298719772,
#    'recall': 0.9874902267396404,
#    'f1-score': 0.9407821229050279,
#    'support': 1279}, 'r': {'precision': 0.8024691358024691,
#    'recall': 0.3125,
#    'f1-score': 0.44982698961937717,
#    'support': 208}, 'accuracy': 0.8930733019502354, 'macro avg': {'precision': 0.8503810828372231,
#    'recall': 0.6499951133698202,
#    'f1-score': 0.6953045562622026,
#    'support': 1487}, 'weighted avg': {'precision': 0.8848892840976278,
#    'recall': 0.8930733019502354,
#    'f1-score': 0.8721078339181986,
#    'support': 1487}},
#  (0.06,
#   0.075): {'g': {'precision': 0.889741800418702,
#    'recall': 0.99687255668491,
#    'f1-score': 0.9402654867256637,
#    'support': 1279}, 'r': {'precision': 0.9259259259259259,
#    'recall': 0.2403846153846154,
#    'f1-score': 0.3816793893129771,
#    'support': 208}, 'accuracy': 0.8910558170813719, 'macro avg': {'precision': 0.907833863172314,
#    'recall': 0.6186285860347627,
#    'f1-score': 0.6609724380193204,
#    'support': 1487}, 'weighted avg': {'precision': 0.8948031979341712,
#    'recall': 0.8910558170813719,
#    'f1-score': 0.8621310494278569,
#    'support': 1487}},
#  (0.065,
#   0.075): {'g': {'precision': 0.886726893676164,
#    'recall': 0.9976544175136826,
#    'f1-score': 0.9389256806475349,
#    'support': 1279}, 'r': {'precision': 0.9375,
#    'recall': 0.21634615384615385,
#    'f1-score': 0.35156250000000006,
#    'support': 208}, 'accuracy': 0.8883658372562205, 'macro avg': {'precision': 0.912113446838082,
#    'recall': 0.6070002856799182,
#    'f1-score': 0.6452440903237675,
#    'support': 1487}, 'weighted avg': {'precision': 0.8938289825230757,
#    'recall': 0.8883658372562205,
#    'f1-score': 0.8567659351366491,
#    'support': 1487}},
#  (0.07,
#   0.075): {'g': {'precision': 0.8844290657439446,
#    'recall': 0.9992181391712275,
#    'f1-score': 0.9383259911894273,
#    'support': 1279}, 'r': {'precision': 0.9761904761904762,
#    'recall': 0.1971153846153846,
#    'f1-score': 0.32799999999999996,
#    'support': 208}, 'accuracy': 0.887020847343645, 'macro avg': {'precision': 0.9303097709672103,
#    'recall': 0.5981667618933061,
#    'f1-score': 0.6331629955947136,
#    'support': 1487}, 'weighted avg': {'precision': 0.8972645555710318,
#    'recall': 0.887020847343645,
#    'f1-score': 0.8529542318300454,
#    'support': 1487}},
#  (0.075,
#   0.075): {'g': {'precision': 0.8820689655172413,
#    'recall': 1.0,
#    'f1-score': 0.9373396848662513,
#    'support': 1279}, 'r': {'precision': 1.0,
#    'recall': 0.1778846153846154,
#    'f1-score': 0.3020408163265306,
#    'support': 208}, 'accuracy': 0.8850033624747814, 'macro avg': {'precision': 0.9410344827586207,
#    'recall': 0.5889423076923077,
#    'f1-score': 0.6196902505963909,
#    'support': 1487}, 'weighted avg': {'precision': 0.8985650349001694,
#    'recall': 0.8850033624747814,
#    'f1-score': 0.8484747456219596,
#    'support': 1487}},
#  (0.08,
#   0.075): {'g': {'precision': 0.8796423658872077,
#    'recall': 1.0,
#    'f1-score': 0.9359678009513355,
#    'support': 1279}, 'r': {'precision': 1.0,
#    'recall': 0.15865384615384615,
#    'f1-score': 0.2738589211618257,
#    'support': 208}, 'accuracy': 0.8823133826496301, 'macro avg': {'precision': 0.9398211829436038,
#    'recall': 0.5793269230769231,
#    'f1-score': 0.6049133610565806,
#    'support': 1487}, 'weighted avg': {'precision': 0.8964778654806581,
#    'recall': 0.8823133826496301,
#    'f1-score': 0.8433527054595951,
#    'support': 1487}},
#  (0.04,
#   0.08): {'g': {'precision': 0.9211783439490446,
#    'recall': 0.9046129788897577,
#    'f1-score': 0.9128205128205129,
#    'support': 1279}, 'r': {'precision': 0.47186147186147187,
#    'recall': 0.5240384615384616,
#    'f1-score': 0.4965831435079727,
#    'support': 208}, 'accuracy': 0.85137861466039, 'macro avg': {'precision': 0.6965199079052582,
#    'recall': 0.7143257202141096,
#    'f1-score': 0.7047018281642428,
#    'support': 1487}, 'weighted avg': {'precision': 0.8583283712562301,
#    'recall': 0.85137861466039,
#    'f1-score': 0.854597666272424,
#    'support': 1487}},
#  (0.045,
#   0.08): {'g': {'precision': 0.9118975903614458,
#    'recall': 0.9468334636434714,
#    'f1-score': 0.9290372075182202,
#    'support': 1279}, 'r': {'precision': 0.5723270440251572,
#    'recall': 0.4375,
#    'f1-score': 0.4959128065395095,
#    'support': 208}, 'accuracy': 0.8755884330867518, 'macro avg': {'precision': 0.7421123171933015,
#    'recall': 0.6921667318217357,
#    'f1-score': 0.7124750070288648,
#    'support': 1487}, 'weighted avg': {'precision': 0.864398818580714,
#    'recall': 0.8755884330867518,
#    'f1-score': 0.8684522206967193,
#    'support': 1487}},
#  (0.05,
#   0.08): {'g': {'precision': 0.9042784626540972,
#    'recall': 0.9749804534792806,
#    'f1-score': 0.9382994732881866,
#    'support': 1279}, 'r': {'precision': 0.7037037037037037,
#    'recall': 0.36538461538461536,
#    'f1-score': 0.48101265822784806,
#    'support': 208}, 'accuracy': 0.8897108271687962, 'macro avg': {'precision': 0.8039910831789004,
#    'recall': 0.670182534431948,
#    'f1-score': 0.7096560657580173,
#    'support': 1487}, 'weighted avg': {'precision': 0.8762222757935176,
#    'recall': 0.8897108271687962,
#    'f1-score': 0.8743346733335461,
#    'support': 1487}},
#  (0.055,
#   0.08): {'g': {'precision': 0.8976545842217484,
#    'recall': 0.9874902267396404,
#    'f1-score': 0.9404318689501117,
#    'support': 1279}, 'r': {'precision': 0.8,
#    'recall': 0.3076923076923077,
#    'f1-score': 0.4444444444444444,
#    'support': 208}, 'accuracy': 0.8924008069939475, 'macro avg': {'precision': 0.8488272921108742,
#    'recall': 0.647591267215974,
#    'f1-score': 0.692438156697278,
#    'support': 1487}, 'weighted avg': {'precision': 0.8839947634294661,
#    'recall': 0.8924008069939475,
#    'f1-score': 0.8710536683467633,
#    'support': 1487}},
#  (0.06,
#   0.08): {'g': {'precision': 0.8891213389121339,
#    'recall': 0.99687255668491,
#    'f1-score': 0.9399189089568744,
#    'support': 1279}, 'r': {'precision': 0.9245283018867925,
#    'recall': 0.23557692307692307,
#    'f1-score': 0.37547892720306514,
#    'support': 208}, 'accuracy': 0.8903833221250841, 'macro avg': {'precision': 0.9068248203994631,
#    'recall': 0.6162247398809165,
#    'f1-score': 0.6576989180799697,
#    'support': 1487}, 'weighted avg': {'precision': 0.8940740277478628,
#    'recall': 0.8903833221250841,
#    'f1-score': 0.8609656364586954,
#    'support': 1487}},
#  (0.065,
#   0.08): {'g': {'precision': 0.8861111111111111,
#    'recall': 0.9976544175136826,
#    'f1-score': 0.9385803604266274,
#    'support': 1279}, 'r': {'precision': 0.9361702127659575,
#    'recall': 0.21153846153846154,
#    'f1-score': 0.3450980392156863,
#    'support': 208}, 'accuracy': 0.8876933422999328, 'macro avg': {'precision': 0.9111406619385343,
#    'recall': 0.604596439526072,
#    'f1-score': 0.6418391998211569,
#    'support': 1487}, 'weighted avg': {'precision': 0.8931133257339813,
#    'recall': 0.8876933422999328,
#    'f1-score': 0.8555646759532745,
#    'support': 1487}},
#  (0.07,
#   0.08): {'g': {'precision': 0.8838174273858921,
#    'recall': 0.9992181391712275,
#    'f1-score': 0.9379816513761469,
#    'support': 1279}, 'r': {'precision': 0.975609756097561,
#    'recall': 0.19230769230769232,
#    'f1-score': 0.32128514056224905,
#    'support': 208}, 'accuracy': 0.8863483523873571, 'macro avg': {'precision': 0.9297135917417265,
#    'recall': 0.5957629157394599,
#    'f1-score': 0.629633395969198,
#    'support': 1487}, 'weighted avg': {'precision': 0.8966572420274705,
#    'recall': 0.8863483523873571,
#    'f1-score': 0.8517187904149559,
#    'support': 1487}},
#  (0.075,
#   0.08): {'g': {'precision': 0.8808539944903582,
#    'recall': 1.0,
#    'f1-score': 0.9366532405712193,
#    'support': 1279}, 'r': {'precision': 1.0,
#    'recall': 0.16826923076923078,
#    'f1-score': 0.2880658436213992,
#    'support': 208}, 'accuracy': 0.8836583725622058, 'macro avg': {'precision': 0.9404269972451791,
#    'recall': 0.5841346153846154,
#    'f1-score': 0.6123595420963093,
#    'support': 1487}, 'weighted avg': {'precision': 0.89752001274591,
#    'recall': 0.8836583725622058,
#    'f1-score': 0.8459295159138135,
#    'support': 1487}},
#  (0.08,
#   0.08): {'g': {'precision': 0.8778311599176389,
#    'recall': 1.0,
#    'f1-score': 0.9349415204678362,
#    'support': 1279}, 'r': {'precision': 1.0,
#    'recall': 0.14423076923076922,
#    'f1-score': 0.25210084033613445,
#    'support': 208}, 'accuracy': 0.8802958977807667, 'macro avg': {'precision': 0.9389155799588195,
#    'recall': 0.5721153846153846,
#    'f1-score': 0.5935211804019853,
#    'support': 1487}, 'weighted avg': {'precision': 0.8949200091019907,
#    'recall': 0.8802958977807667,
#    'f1-score': 0.8394264824937985,
#    'support': 1487}},
#  (0.04,
#   0.03): {'g': {'precision': 0.9537444933920705,
#    'recall': 0.6770914777169664,
#    'f1-score': 0.7919524462734339,
#    'support': 1279}, 'r': {'precision': 0.2867012089810017,
#    'recall': 0.7980769230769231,
#    'f1-score': 0.42185514612452346,
#    'support': 208}, 'accuracy': 0.6940147948890383, 'macro avg': {'precision': 0.6202228511865361,
#    'recall': 0.7375842003969448,
#    'f1-score': 0.6069037961989787,
#    'support': 1487}, 'weighted avg': {'precision': 0.8604391785585114,
#    'recall': 0.6940147948890383,
#    'f1-score': 0.7401836241947698,
#    'support': 1487}},
#  (0.045,
#   0.03): {'g': {'precision': 0.9539121114683816,
#    'recall': 0.6958561376075059,
#    'f1-score': 0.8047016274864377,
#    'support': 1279}, 'r': {'precision': 0.29783393501805056,
#    'recall': 0.7932692307692307,
#    'f1-score': 0.43307086614173235,
#    'support': 208}, 'accuracy': 0.7094821788836584, 'macro avg': {'precision': 0.6258730232432161,
#    'recall': 0.7445626841883684,
#    'f1-score': 0.618886246814085,
#    'support': 1487}, 'weighted avg': {'precision': 0.8621405844329622,
#    'recall': 0.7094821788836584,
#    'f1-score': 0.7527183064644479,
#    'support': 1487}},
#  (0.05,
#   0.03): {'g': {'precision': 0.9523809523809523,
#    'recall': 0.7036747458952306,
#    'f1-score': 0.8093525179856115,
#    'support': 1279}, 'r': {'precision': 0.3007380073800738,
#    'recall': 0.7836538461538461,
#    'f1-score': 0.4346666666666667,
#    'support': 208}, 'accuracy': 0.714862138533961, 'macro avg': {'precision': 0.6265594798805131,
#    'recall': 0.7436642960245383,
#    'f1-score': 0.6220095923261391,
#    'support': 1487}, 'weighted avg': {'precision': 0.8612298208677158,
#    'recall': 0.714862138533961,
#    'f1-score': 0.756941854183096,
#    'support': 1487}},
#  (0.055,
#   0.03): {'g': {'precision': 0.9504741833508957,
#    'recall': 0.7052384675527756,
#    'f1-score': 0.8096947935368044,
#    'support': 1279}, 'r': {'precision': 0.2992565055762082,
#    'recall': 0.7740384615384616,
#    'f1-score': 0.43163538873994634,
#    'support': 208}, 'accuracy': 0.714862138533961, 'macro avg': {'precision': 0.6248653444635519,
#    'recall': 0.7396384645456187,
#    'f1-score': 0.6206650911383753,
#    'support': 1487}, 'weighted avg': {'precision': 0.8593825377711142,
#    'recall': 0.714862138533961,
#    'f1-score': 0.7568122406129668,
#    'support': 1487}},
#  (0.06,
#   0.03): {'g': {'precision': 0.9505783385909569,
#    'recall': 0.7068021892103206,
#    'f1-score': 0.810762331838565,
#    'support': 1279}, 'r': {'precision': 0.3003731343283582,
#    'recall': 0.7740384615384616,
#    'f1-score': 0.43279569892473113,
#    'support': 208}, 'accuracy': 0.7162071284465367, 'macro avg': {'precision': 0.6254757364596575,
#    'recall': 0.7404203253743911,
#    'f1-score': 0.621779015381648,
#    'support': 1487}, 'weighted avg': {'precision': 0.8596283167438683,
#    'recall': 0.7162071284465367,
#    'f1-score': 0.7578927557483986,
#    'support': 1487}},
#  (0.04,
#   0.035): {'g': {'precision': 0.9496021220159151,
#    'recall': 0.8397185301016419,
#    'f1-score': 0.891286307053942,
#    'support': 1279}, 'r': {'precision': 0.4241573033707865,
#    'recall': 0.7259615384615384,
#    'f1-score': 0.5354609929078015,
#    'support': 208}, 'accuracy': 0.8238063214525891, 'macro avg': {'precision': 0.6868797126933508,
#    'recall': 0.7828400342815902,
#    'f1-score': 0.7133736499808717,
#    'support': 1487}, 'weighted avg': {'precision': 0.8761034520238594,
#    'recall': 0.8238063214525891,
#    'f1-score': 0.8415138354047171,
#    'support': 1487}},
#  (0.045,
#   0.035): {'g': {'precision': 0.9490229396771452,
#    'recall': 0.8733385457388585,
#    'f1-score': 0.9096091205211726,
#    'support': 1279}, 'r': {'precision': 0.4774193548387097,
#    'recall': 0.7115384615384616,
#    'f1-score': 0.5714285714285715,
#    'support': 208}, 'accuracy': 0.8507061197041023, 'macro avg': {'precision': 0.7132211472579275,
#    'recall': 0.7924385036386601,
#    'f1-score': 0.740518845974872,
#    'support': 1487}, 'weighted avg': {'precision': 0.883055524985555,
#    'recall': 0.8507061197041023,
#    'f1-score': 0.8623047800966527,
#    'support': 1487}},
#  (0.05,
#   0.035): {'g': {'precision': 0.9462809917355371,
#    'recall': 0.8952306489444879,
#    'f1-score': 0.9200482121333868,
#    'support': 1279}, 'r': {'precision': 0.516245487364621,
#    'recall': 0.6875,
#    'f1-score': 0.5896907216494846,
#    'support': 208}, 'accuracy': 0.8661735036987223, 'macro avg': {'precision': 0.7312632395500791,
#    'recall': 0.791365324472244,
#    'f1-score': 0.7548694668914357,
#    'support': 1487}, 'weighted avg': {'precision': 0.8861280765309973,
#    'recall': 0.8661735036987223,
#    'f1-score': 0.8738381529399424,
#    'support': 1487}},
#  (0.055,
#   0.035): {'g': {'precision': 0.9434889434889435,
#    'recall': 0.9007036747458952,
#    'f1-score': 0.9216,
#    'support': 1279}, 'r': {'precision': 0.5225563909774437,
#    'recall': 0.6682692307692307,
#    'f1-score': 0.5864978902953587,
#    'support': 208}, 'accuracy': 0.8681909885675857, 'macro avg': {'precision': 0.7330226672331936,
#    'recall': 0.784486452757563,
#    'f1-score': 0.7540489451476793,
#    'support': 1487}, 'weighted avg': {'precision': 0.8846093396406638,
#    'recall': 0.8681909885675857,
#    'f1-score': 0.8747262684475015,
#    'support': 1487}},
#  (0.06,
#   0.035): {'g': {'precision': 0.9415109666937449,
#    'recall': 0.9061767005473026,
#    'f1-score': 0.9235059760956176,
#    'support': 1279}, 'r': {'precision': 0.53125,
#    'recall': 0.6538461538461539,
#    'f1-score': 0.5862068965517242,
#    'support': 208}, 'accuracy': 0.8708809683927371, 'macro avg': {'precision': 0.7363804833468724,
#    'recall': 0.7800114271967282,
#    'f1-score': 0.7548564363236709,
#    'support': 1487}, 'weighted avg': {'precision': 0.884124093074176,
#    'recall': 0.8708809683927371,
#    'f1-score': 0.8763249347068282,
#    'support': 1487}}}

# %%
# %matplotlib notebook
plt.ion()

n = '375'
HR = sample_timeseries(HR_data_scaled_averaged[n])
BP = sample_timeseries(BP_data_scaled_averaged[n])

fig1 = plt.figure()
ax1 = fig1.add_subplot(211)
ax1.set_ylim(0,1)
ax2 = fig1.add_subplot(212)
ax2.set_ylim(0,1)

t = 0
SEVERITY_ACC = np.zeros(N_SAMPLES_MEMORY)
BP_last_elem = None
for HRv, BPv in zip(HR, BP):
    if BP_last_elem == None:
        BP_line_8D, _, _ = encoder.predict(np.array([BPv]))
        HR_line_8D, _, _ = encoder.predict(np.array([HRv]))
        c = check_severity(HR_line_8D, BP_line_8D, 0.185, 0.060)

        ax1.plot(range(t, t + len(HRv)), HRv, color=f'{c}', linestyle='-')
        ax2.plot(range(t, t + len(BPv)), BPv, color=f'{c}', linestyle='-')

        t += len(BPv)
    else:
        BP_line_8D, _, _ = encoder.predict(np.array([BPv]))
        HR_line_8D, _, _ = encoder.predict(np.array([HRv]))
        c = check_severity(HR_line_8D, BP_line_8D, 0.185, 0.060)

        time_range = range(t-1, t + len(BPv)) 
        BPv = np.concatenate(([BP_last_elem], BPv))
        HRv = np.concatenate(([HR_last_elem], HRv))
        ax1.plot(time_range, HRv, color=f'{c}', linestyle='-')
        ax2.plot(time_range, BPv, color=f'{c}', linestyle='-')

        t += len(BPv) - 1
    fig1.canvas.draw()
    BP_last_elem = BPv[-1]
    HR_last_elem = HRv[-1]
# Out:
# <img src="data:image/png;base64,..." width="640">
