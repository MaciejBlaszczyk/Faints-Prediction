# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"  # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"] = '-1'
import math

import numpy as np
import pandas as pd
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from matplotlib import pyplot as plt

from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, TimeDistributed, BatchNormalization
from keras.callbacks import EarlyStopping

import datetime as dt

from vrae.vrae import VRAE
from torch.utils.data import TensorDataset
import torch
# Out:
# Using TensorFlow backend.

# %%
path = "C:/Users/OPTIMUSPRIME/Desktop/Studia/Magisterka/Faints-Prediction/"
BP_filename = "BP.csv"
HR_filename = "HR.csv"

train_indices =  [str(indx[0]) for indx in pd.read_csv(path + "DATA/training_set.txt").values.tolist()]
test_indices =  [str(indx[0]) for indx in pd.read_csv(path + "DATA/test_set.txt").values.tolist()]
validation_indices =  [str(indx[0]) for indx in pd.read_csv(path + "DATA/validation_set.txt").values.tolist()]
all_indices = train_indices + test_indices + validation_indices

# %%
def shift(xs, n):
    if n >= 0:
        return np.concatenate((np.full(n, np.nan), xs[:-n]))
    else:
        return np.concatenate((xs[-n:], np.full(-n, np.nan)))

    
def series_to_supervised(share_prices, timestamps, input_time_steps, dropnan=True):
    share_prices_df = pd.DataFrame(share_prices)
    timestamps_df = pd.DataFrame(timestamps)
    share_prices_timeseries = list()
    timestamps_timeseries = list()
    
    for i in range(input_time_steps-1, -1, -1):
        share_prices_timeseries.append(share_prices_df.shift(i))
        timestamps_timeseries.append(timestamps_df.shift(i))
    
    aggregated_share_prices = pd.concat(share_prices_timeseries, axis=1)
    aggregated_timestamps = pd.concat(timestamps_timeseries, axis=1)
    
    if dropnan:
        aggregated_share_prices.dropna(inplace=True)
        aggregated_timestamps.dropna(inplace=True)

    aggregated_timestamps = aggregated_timestamps.values
    aggregated_share_prices = aggregated_share_prices.values
    
    not_overlapping_indexes = range(0, 
                                    len(aggregated_share_prices), 
                                    input_time_steps)
    
    aggregated_timestamps = aggregated_timestamps[not_overlapping_indexes]
    aggregated_share_prices = aggregated_share_prices[not_overlapping_indexes]
    return aggregated_share_prices, aggregated_timestamps
 

def split(BP_data, HR_data, col, time_steps):
    X = []
    y = []

    BP_supervised, HR_supervised = series_to_supervised(BP_data[col], HR_data[col], time_steps)
    for BP_interval, HR_interval in zip(BP_supervised, HR_supervised):
        BP_HR_interval = []
        for BP_time_step, HR_time_step in zip(BP_interval, HR_interval):
            BP_HR_interval.append([BP_time_step, HR_time_step])
        X.append(BP_HR_interval)
        if labels[col] == 'Synkope': label = [0., 1.] 
        else: label = [1., 0.]
        y.append(label)
    return np.array(X), np.array(y)


def split_df(BP_data, HR_data, time_steps):
    X = np.array([])
    y = np.array([])
    for col in BP_data:
        X_single, y_single = split(BP_data, HR_data, col, time_steps)
        if X.size == 0:
            X = X_single
            y = y_single
        else:
            X = np.concatenate((X, X_single))
            y = np.concatenate((y, y_single))
    return np.array(X), np.array(y)

# %%
BP_data = pd.read_csv(path + "DATA/" + BP_filename, low_memory=False)[all_indices]
HR_data = pd.read_csv(path + "DATA/" + HR_filename, low_memory=False)[all_indices]
labels = {col: BP_data[col].iloc[0] for col in BP_data}

BP_max_value = BP_data.iloc[1:].astype(np.float32).max().max()
BP_min_value = BP_data.iloc[1:].astype(np.float32).min().min()
HR_max_value = HR_data.iloc[1:].astype(np.float32).max().max()
HR_min_value = HR_data.iloc[1:].astype(np.float32).min().min()

BP_scaler = MinMaxScaler().fit(np.array([BP_min_value, BP_max_value]).reshape(-1,1))
HR_scaler = MinMaxScaler().fit(np.array([HR_min_value, HR_max_value]).reshape(-1,1))

BP_data_scaled = BP_data.iloc[1:].astype(np.float32).copy()
BP_data_scaled[all_indices] = BP_scaler.transform(BP_data_scaled[all_indices])

HR_data_scaled = HR_data.iloc[1:].astype(np.float32).copy()
HR_data_scaled[all_indices] = HR_scaler.transform(HR_data_scaled[all_indices])

# %%
part_to_drop = 0.4
BP_data_scaled_trimmed = BP_data_scaled.copy()
HR_data_scaled_trimmed = HR_data_scaled.copy()
for col in BP_data_scaled_trimmed:
    n_rows_to_drop = int(part_to_drop * np.count_nonzero(~np.isnan(BP_data_scaled_trimmed[col])))

    BP_data_scaled_trimmed[col] = shift(BP_data_scaled_trimmed[col], -n_rows_to_drop)
    HR_data_scaled_trimmed[col] = shift(HR_data_scaled_trimmed[col], -n_rows_to_drop)

# %%
#32 -> 8 -> 2
#64 -> 16 -> 2
#128 -> 32 -> 2
#wybor parametrow

# time_steps = [32, 64, 128]
time_steps = [128, 64, 32] 
hidden_sizes = [32, 16, 8]
# r_layers = [0, 2, 3, 4]
# r_layers = [2]
# LSTM_cells = [1, 16, 64, 256]
# LSTM_cells = [64]
# neurons = [5, 20, 50]
# neurons = [5]
# epochs = [1, 2, 3, 4, 5]
epochs = [10, 40, 60]
# batch_size = [32, 64, 128]
batch_sizes = [32, 64, 128]
# dropout_rates = [0.2, 0.4, 0.0]
# clips = [True, False]

hidden_size = 60 # 30? 60?
hidden_layer_depth = 1 #2?
latent_length = 2 #10? 20?
batch_size = 32
learning_rate = 0.0005
n_epochs = 40 #20? 80?
dropout_rate = 0.2
optimizer = 'Adam'  # options: ADAM, SGD
cuda = False  # options: True, False
print_every = 30
clip = True  # options: True, False
max_grad_norm = 5
loss = 'MSELoss'  # options: SmoothL1Loss, MSELoss
block = 'LSTM'  # options: LSTM, GRU

# %%
def choose_color(label):
    if label[0] == 1.0:
        return 'r'
    elif label[0] == 0.0:
        return 'b'
    else:
        return 'm'
    
def plot_latent_space(X, Y, typ, directory):
    latent_space = vrae.transform(TensorDataset(torch.from_numpy(X)))
    
    lsl = latent_space.shape[0]

    X_BP_means = scale([np.mean(x[:,0]) for x in X], (0,100))
    X_HR_means = scale([np.mean(x[:,1]) for x in X], (0,100))
    label_colors = [choose_color(y) for y in Y]

    plt.figure(figsize=(12,8))
    plt.scatter(latent_space[:, 0], latent_space[:, 1], c=X_HR_means[:lsl], s=5, cmap='gist_rainbow')
    plt.savefig(f"{directory}/{typ}_HR_MEANS_LS.png")

    plt.figure(figsize=(12,8))
    plt.scatter(latent_space[:, 0], latent_space[:, 1], c=X_BP_means[:lsl], s=5, cmap='gist_rainbow')
    plt.savefig(f"{directory}/{typ}_BP_MEANS_LS.png")

    plt.figure(figsize=(12,8))
    plt.scatter(latent_space[:, 0], latent_space[:, 1], c=label_colors[:lsl], s=5)
    plt.savefig(f"{directory}/{typ}_LABELS_LS.png")
    plt.close('all')
    
def scale(x, out_range=(-1, 1), axis=None):
    domain = np.min(x, axis), np.max(x, axis)
    y = (x - (domain[1] + domain[0]) / 2) / (domain[1] - domain[0])
    return y * (out_range[1] - out_range[0]) + (out_range[1] + out_range[0]) / 2

# %%
plt.ioff()
for ts, h in zip(time_steps, hidden_sizes):
    X_train, y_train = split_df(BP_data_scaled_trimmed[train_indices], HR_data_scaled_trimmed[train_indices], ts)
    X_test, y_test = split_df(BP_data_scaled_trimmed[test_indices], HR_data_scaled_trimmed[test_indices], ts)
    train_dataset = TensorDataset(torch.from_numpy(X_train))
    test_dataset = TensorDataset(torch.from_numpy(X_test))
    sequence_length = X_train.shape[1]
    number_of_features = X_train.shape[2]
    for e in epochs:
        for bs in batch_sizes:            
            vrae = VRAE(sequence_length=sequence_length,
            number_of_features=number_of_features,
            hidden_size=h,
            hidden_layer_depth=hidden_layer_depth,
            latent_length=latent_length,
            batch_size=bs,
            learning_rate=learning_rate,
            n_epochs=e,
            dropout_rate=dropout_rate,
            optimizer=optimizer,
            cuda=cuda,
            print_every=print_every,
            clip=clip,
            max_grad_norm=max_grad_norm,
            loss=loss,
            block=block,
            dload='a')
            
            epoch_loss, recon_loss, kl_loss = vrae.fit(train_dataset)
            epoch_loss = round(epoch_loss, 2)
            recon_loss = round(recon_loss, 2)
            kl_loss = round(kl_loss, 2)
            directory = "VRAE_results/" + f"LOSS{epoch_loss}_RECONLOSS{recon_loss}_KLLOSS{kl_loss}_LATENT{latent_length}_TS{ts}_BS{bs}_E{e}"
            os.mkdir(directory)
            
            plot_latent_space(X_train, y_train, 'TRAIN', directory)
            plot_latent_space(X_test, y_test, 'TEST', directory)
            del vrae
# Out:
# Epoch: 0
# Batch 30, loss = 214.4090, recon_loss = 214.3918, kl_loss = 0.0172
# Batch 60, loss = 107.5715, recon_loss = 107.4995, kl_loss = 0.0720
# Average loss: 229.6017
# Epoch: 1
# Batch 30, loss = 100.3390, recon_loss = 100.1908, kl_loss = 0.1482
# Batch 60, loss = 113.6138, recon_loss = 113.5305, kl_loss = 0.0833
# Average loss: 109.9032
# Epoch: 2
# Batch 30, loss = 97.2541, recon_loss = 97.2277, kl_loss = 0.0264
# Batch 60, loss = 79.1855, recon_loss = 79.1721, kl_loss = 0.0135
# Average loss: 110.1601
# Epoch: 3
# Batch 30, loss = 112.8470, recon_loss = 112.8438, kl_loss = 0.0033
# Batch 60, loss = 112.7895, recon_loss = 112.7850, kl_loss = 0.0044
# Average loss: 110.6442
# Epoch: 4
# Batch 30, loss = 119.1137, recon_loss = 118.8837, kl_loss = 0.2300
# Batch 60, loss = 89.0413, recon_loss = 88.5265, kl_loss = 0.5148
# Average loss: 109.5991
# Epoch: 5
# Batch 30, loss = 102.1503, recon_loss = 101.5637, kl_loss = 0.5866
# Batch 60, loss = 136.1575, recon_loss = 135.5035, kl_loss = 0.6540
# Average loss: 109.5244
# Epoch: 3
# Batch 30, loss = 123.3570, recon_loss = 123.1229, kl_loss = 0.2341
# Batch 60, loss = 111.1081, recon_loss = 110.4103, kl_loss = 0.6978
# Average loss: 109.0583
# Epoch: 4
# Batch 30, loss = 86.7427, recon_loss = 86.1855, kl_loss = 0.5572
# Batch 60, loss = 90.8075, recon_loss = 90.4004, kl_loss = 0.4071
# Average loss: 109.1282
# Epoch: 5
# Batch 30, loss = 111.4986, recon_loss = 110.6184, kl_loss = 0.8803
# Batch 60, loss = 95.4530, recon_loss = 94.7228, kl_loss = 0.7302
# Average loss: 108.3427
# Epoch: 6
# Batch 30, loss = 113.8654, recon_loss = 113.3184, kl_loss = 0.5470
# Batch 60, loss = 124.7732, recon_loss = 124.0980, kl_loss = 0.6752
# Average loss: 108.2474
# Epoch: 7
# Batch 30, loss = 112.8358, recon_loss = 112.0472, kl_loss = 0.7886
# Batch 60, loss = 88.1227, recon_loss = 87.3404, kl_loss = 0.7823
# Average loss: 107.4165
# Epoch: 8
# Batch 30, loss = 93.2149, recon_loss = 92.3590, kl_loss = 0.8559
# Batch 60, loss = 71.2502, recon_loss = 70.6133, kl_loss = 0.6369
# Average loss: 106.9363
# Epoch: 9
# Batch 30, loss = 100.4218, recon_loss = 99.5015, kl_loss = 0.9203
# Batch 60, loss = 129.3870, recon_loss = 128.2730, kl_loss = 1.1140
# Average loss: 105.2155
# Epoch: 10
# Batch 30, loss = 100.2201, recon_loss = 99.1895, kl_loss = 1.0306
# Batch 60, loss = 118.7806, recon_loss = 117.5459, kl_loss = 1.2347
# Average loss: 105.2199
# Epoch: 11
# Batch 30, loss = 131.0961, recon_loss = 129.8739, kl_loss = 1.2222
# Batch 60, loss = 76.4163, recon_loss = 75.3736, kl_loss = 1.0427
# Average loss: 89.9289
# Epoch: 12
# Batch 30, loss = 73.2268, recon_loss = 70.8780, kl_loss = 2.3488
# Batch 60, loss = 50.0739, recon_loss = 48.7327, kl_loss = 1.3412
# Average loss: 63.5607
# Epoch: 13
# Batch 30, loss = 55.9162, recon_loss = 53.6032, kl_loss = 2.3130
# Batch 60, loss = 81.7271, recon_loss = 79.9389, kl_loss = 1.7882
# Average loss: 59.5412
# Epoch: 14
# Batch 30, loss = 64.0060, recon_loss = 61.9635, kl_loss = 2.0424
# Batch 60, loss = 56.8425, recon_loss = 55.0761, kl_loss = 1.7664
# Average loss: 58.1057
# Epoch: 15
# Batch 30, loss = 53.4035, recon_loss = 51.0285, kl_loss = 2.3750
# Batch 60, loss = 58.0166, recon_loss = 55.6937, kl_loss = 2.3229
# Average loss: 60.3800
# Epoch: 16
# Batch 30, loss = 63.1090, recon_loss = 60.7653, kl_loss = 2.3437
# Batch 60, loss = 45.7563, recon_loss = 43.6009, kl_loss = 2.1554
# Average loss: 55.6929
# Epoch: 17
# Batch 30, loss = 76.7076, recon_loss = 74.7000, kl_loss = 2.0075
# Batch 60, loss = 48.9824, recon_loss = 47.0094, kl_loss = 1.9729
# Average loss: 55.2887
# Epoch: 18
# Batch 30, loss = 43.9595, recon_loss = 42.0948, kl_loss = 1.8648
# Batch 60, loss = 75.1129, recon_loss = 73.0141, kl_loss = 2.0988
# Average loss: 54.9345
# Epoch: 19
# Batch 30, loss = 67.3320, recon_loss = 65.1829, kl_loss = 2.1491
# Batch 60, loss = 66.4571, recon_loss = 64.2825, kl_loss = 2.1746
# Average loss: 53.6560
# Epoch: 20
# Batch 30, loss = 53.1277, recon_loss = 51.0466, kl_loss = 2.0811
# Batch 60, loss = 37.4227, recon_loss = 35.2618, kl_loss = 2.1609
# Average loss: 57.0844
# Epoch: 21
# Batch 30, loss = 49.6837, recon_loss = 47.4699, kl_loss = 2.2138
# Batch 60, loss = 62.0449, recon_loss = 59.4189, kl_loss = 2.6260
# Average loss: 54.5569
# Epoch: 22
# Batch 30, loss = 49.0394, recon_loss = 46.3701, kl_loss = 2.6693
# Batch 60, loss = 64.4038, recon_loss = 62.1792, kl_loss = 2.2247
# Average loss: 53.1352
# Epoch: 23
# Batch 30, loss = 86.9476, recon_loss = 84.6799, kl_loss = 2.2677
# Batch 60, loss = 72.5189, recon_loss = 70.2188, kl_loss = 2.3001
# Average loss: 52.2726
# Epoch: 24
# Batch 30, loss = 38.7108, recon_loss = 36.6413, kl_loss = 2.0695
# Batch 60, loss = 43.5726, recon_loss = 41.1848, kl_loss = 2.3878
# Average loss: 51.5961
# Epoch: 25
# Batch 30, loss = 50.9795, recon_loss = 48.7252, kl_loss = 2.2543
# Batch 60, loss = 41.9108, recon_loss = 39.7508, kl_loss = 2.1600
# Average loss: 53.8138
# Epoch: 26
# Batch 30, loss = 52.9387, recon_loss = 50.9053, kl_loss = 2.0334
# Batch 60, loss = 41.5291, recon_loss = 39.3235, kl_loss = 2.2056
# Average loss: 50.9567
# Epoch: 27
# Batch 30, loss = 60.1462, recon_loss = 57.7347, kl_loss = 2.4114
# Batch 60, loss = 50.6790, recon_loss = 48.4756, kl_loss = 2.2034
# Average loss: 50.1505
# Epoch: 28
# Batch 30, loss = 35.8548, recon_loss = 33.7313, kl_loss = 2.1235
# Batch 60, loss = 66.6229, recon_loss = 64.2281, kl_loss = 2.3947
# Average loss: 51.3294
# Epoch: 29
# Batch 30, loss = 55.7357, recon_loss = 53.5025, kl_loss = 2.2332
# Batch 60, loss = 64.1028, recon_loss = 61.8976, kl_loss = 2.2052
# Average loss: 50.1869
# Epoch: 30
# Batch 30, loss = 48.3062, recon_loss = 45.9751, kl_loss = 2.3311
# Batch 60, loss = 51.0891, recon_loss = 48.9495, kl_loss = 2.1395
# Average loss: 48.9481
# Epoch: 31
# Batch 30, loss = 48.5602, recon_loss = 46.2938, kl_loss = 2.2664
# Batch 60, loss = 50.7505, recon_loss = 48.3340, kl_loss = 2.4165
# Average loss: 50.0203
# Epoch: 32
# Batch 30, loss = 63.3898, recon_loss = 60.9000, kl_loss = 2.4898
# Batch 60, loss = 40.4418, recon_loss = 38.1481, kl_loss = 2.2936
# Average loss: 50.3325
# Epoch: 33
# Batch 30, loss = 51.4822, recon_loss = 49.3166, kl_loss = 2.1656
# Batch 60, loss = 39.2119, recon_loss = 37.1060, kl_loss = 2.1059
# Average loss: 47.5655
# Epoch: 34
# Batch 30, loss = 50.5504, recon_loss = 48.4071, kl_loss = 2.1433
# Batch 60, loss = 51.0454, recon_loss = 48.9316, kl_loss = 2.1138
# Average loss: 47.6864
# Epoch: 35
# Batch 30, loss = 41.5891, recon_loss = 39.0724, kl_loss = 2.5167
# Batch 60, loss = 36.3156, recon_loss = 33.7764, kl_loss = 2.5391
# Average loss: 49.0415
# Epoch: 36
# Batch 30, loss = 41.8791, recon_loss = 39.3825, kl_loss = 2.4966
# Batch 60, loss = 48.0012, recon_loss = 45.6721, kl_loss = 2.3292
# Average loss: 47.7640
# Epoch: 37
# Batch 30, loss = 45.4647, recon_loss = 43.1111, kl_loss = 2.3536
# Batch 60, loss = 49.9273, recon_loss = 47.3908, kl_loss = 2.5365
# Average loss: 47.2695
# Epoch: 38
# Batch 30, loss = 31.6525, recon_loss = 29.3203, kl_loss = 2.3322
# Batch 60, loss = 38.2836, recon_loss = 36.0854, kl_loss = 2.1983
# Average loss: 44.6596
# Epoch: 39
# Batch 30, loss = 56.3053, recon_loss = 53.7546, kl_loss = 2.5507
# Batch 60, loss = 71.0837, recon_loss = 68.6520, kl_loss = 2.4317
# Average loss: 49.3133
# Epoch: 0
# Batch 30, loss = 370.3885, recon_loss = 370.3414, kl_loss = 0.0471
# Average loss: 726.5550
# Epoch: 1
# Batch 30, loss = 224.6447, recon_loss = 224.1020, kl_loss = 0.5427
# Average loss: 227.9771
# Epoch: 2
# Batch 30, loss = 210.7040, recon_loss = 210.2254, kl_loss = 0.4786
# Average loss: 223.6625
# Epoch: 3
# Batch 30, loss = 177.3749, recon_loss = 176.9307, kl_loss = 0.4442
# Average loss: 223.6829
# Epoch: 4
# Batch 30, loss = 200.1509, recon_loss = 199.5134, kl_loss = 0.6376
# Average loss: 221.8389
# Epoch: 5
# Batch 30, loss = 175.3889, recon_loss = 174.7864, kl_loss = 0.6025
# Average loss: 219.8704
# Epoch: 6
# Batch 30, loss = 199.4771, recon_loss = 198.2809, kl_loss = 1.1962
# Average loss: 219.4424
# Epoch: 7
# Batch 30, loss = 227.6604, recon_loss = 226.9491, kl_loss = 0.7113
# Average loss: 219.0794
# Epoch: 8
# Batch 30, loss = 171.6953, recon_loss = 171.1114, kl_loss = 0.5839
# Average loss: 218.0333
# Epoch: 9
# Batch 30, loss = 220.4093, recon_loss = 219.2905, kl_loss = 1.1188
# Average loss: 216.0084
# Epoch: 10
# Batch 30, loss = 183.2443, recon_loss = 182.7020, kl_loss = 0.5423
# Average loss: 215.7641
# Epoch: 11
# Batch 30, loss = 95.8392, recon_loss = 94.7207, kl_loss = 1.1185
# Average loss: 144.4985
# Epoch: 12
# Batch 30, loss = 119.0573, recon_loss = 118.0498, kl_loss = 1.0075
# Average loss: 135.7824
# Epoch: 13
# Batch 30, loss = 134.4657, recon_loss = 133.4205, kl_loss = 1.0452
# Average loss: 128.3066
# Batch 60, loss = 84.9294, recon_loss = 84.1231, kl_loss = 0.8063
# Average loss: 97.8406
# Epoch: 7
# Batch 30, loss = 57.7734, recon_loss = 56.6522, kl_loss = 1.1211
# Batch 60, loss = 59.2824, recon_loss = 58.3058, kl_loss = 0.9766
# Average loss: 66.0079
# Epoch: 8
# Batch 30, loss = 66.1394, recon_loss = 65.2643, kl_loss = 0.8751
# Batch 60, loss = 91.6266, recon_loss = 90.6646, kl_loss = 0.9620
# Average loss: 62.8727
# Epoch: 9
# Batch 30, loss = 39.2952, recon_loss = 38.1908, kl_loss = 1.1044
# Batch 60, loss = 37.0525, recon_loss = 35.5335, kl_loss = 1.5191
# Average loss: 59.4721
# Epoch: 10
# Batch 30, loss = 84.3707, recon_loss = 83.0880, kl_loss = 1.2827
# Batch 60, loss = 79.7787, recon_loss = 78.2090, kl_loss = 1.5697
# Average loss: 57.7670
# Epoch: 11
# Batch 30, loss = 41.5549, recon_loss = 40.2720, kl_loss = 1.2829
# Batch 60, loss = 33.2665, recon_loss = 31.7445, kl_loss = 1.5220
# Average loss: 55.9269
# Epoch: 12
# Batch 30, loss = 64.8655, recon_loss = 63.5562, kl_loss = 1.3093
# Batch 60, loss = 67.1155, recon_loss = 65.4119, kl_loss = 1.7036
# Average loss: 55.4009
# Epoch: 13
# Batch 30, loss = 44.4833, recon_loss = 43.0140, kl_loss = 1.4693
# Batch 60, loss = 58.7501, recon_loss = 57.3172, kl_loss = 1.4329
# Average loss: 56.2650
# Epoch: 14
# Batch 30, loss = 50.1360, recon_loss = 48.5033, kl_loss = 1.6326
# Batch 60, loss = 45.8560, recon_loss = 44.1204, kl_loss = 1.7355
# Average loss: 54.4761
# Epoch: 15
# Batch 30, loss = 43.9229, recon_loss = 42.3823, kl_loss = 1.5406
# Batch 60, loss = 38.3889, recon_loss = 36.8484, kl_loss = 1.5405
# Average loss: 54.4683
# Epoch: 16
# Batch 30, loss = 54.3420, recon_loss = 53.1114, kl_loss = 1.2305
# Batch 60, loss = 36.2029, recon_loss = 34.8487, kl_loss = 1.3541
# Average loss: 54.0149
# Epoch: 17
# Batch 30, loss = 41.7649, recon_loss = 40.5475, kl_loss = 1.2174
# Batch 60, loss = 58.7928, recon_loss = 57.5839, kl_loss = 1.2088
# Average loss: 53.8750
# Epoch: 18
# Batch 30, loss = 46.3408, recon_loss = 45.1073, kl_loss = 1.2335
# Batch 60, loss = 81.4373, recon_loss = 80.1275, kl_loss = 1.3098
# Average loss: 54.9032
# Epoch: 19
# Batch 30, loss = 52.5031, recon_loss = 50.8105, kl_loss = 1.6925
# Batch 60, loss = 42.5479, recon_loss = 41.1813, kl_loss = 1.3666
# Average loss: 55.1053
# Epoch: 20
# Batch 30, loss = 59.2828, recon_loss = 57.8072, kl_loss = 1.4756
# Batch 60, loss = 51.5489, recon_loss = 50.2347, kl_loss = 1.3142
# Average loss: 53.5997
# Epoch: 21
# Batch 30, loss = 60.0715, recon_loss = 58.5848, kl_loss = 1.4867
# Batch 60, loss = 40.9058, recon_loss = 39.3114, kl_loss = 1.5944
# Average loss: 54.2964
# Epoch: 22
# Batch 30, loss = 58.2937, recon_loss = 56.8172, kl_loss = 1.4765
# Batch 60, loss = 38.8024, recon_loss = 37.2865, kl_loss = 1.5159
# Average loss: 53.2058
# Epoch: 23
# Batch 30, loss = 69.8085, recon_loss = 68.3973, kl_loss = 1.4112
# Batch 60, loss = 44.9069, recon_loss = 43.3694, kl_loss = 1.5375
# Average loss: 53.7090
# Epoch: 24
# Batch 30, loss = 58.3184, recon_loss = 56.7875, kl_loss = 1.5309
# Batch 60, loss = 73.4997, recon_loss = 72.1889, kl_loss = 1.3109
# Average loss: 54.5615
# Epoch: 25
# Batch 30, loss = 50.2949, recon_loss = 48.9187, kl_loss = 1.3762
# Batch 60, loss = 34.7016, recon_loss = 33.3892, kl_loss = 1.3123
# Average loss: 52.6984
# Epoch: 26
# Batch 30, loss = 64.1927, recon_loss = 62.7412, kl_loss = 1.4516
# Batch 60, loss = 41.2053, recon_loss = 39.9958, kl_loss = 1.2096
# Average loss: 51.8995
# Epoch: 27
# Batch 30, loss = 30.0906, recon_loss = 28.5340, kl_loss = 1.5567
# Batch 60, loss = 41.6441, recon_loss = 40.2825, kl_loss = 1.3615
# Average loss: 51.8216
# Epoch: 28
# Batch 30, loss = 38.7126, recon_loss = 37.2171, kl_loss = 1.4955
# Batch 60, loss = 67.2727, recon_loss = 65.9002, kl_loss = 1.3725
# Average loss: 53.0030
# Epoch: 29
# Batch 30, loss = 37.6014, recon_loss = 36.0276, kl_loss = 1.5738
# Batch 60, loss = 51.3797, recon_loss = 50.0202, kl_loss = 1.3595
# Average loss: 52.6120
# Epoch: 30
# Batch 30, loss = 41.4729, recon_loss = 39.9586, kl_loss = 1.5142
# Batch 60, loss = 57.1844, recon_loss = 55.8937, kl_loss = 1.2907
# Average loss: 55.0045
# Epoch: 31
# Batch 30, loss = 49.2823, recon_loss = 47.7976, kl_loss = 1.4847
# Batch 60, loss = 59.4451, recon_loss = 58.0577, kl_loss = 1.3875
# Average loss: 52.4434
# Epoch: 32
# Batch 30, loss = 45.9691, recon_loss = 44.5541, kl_loss = 1.4150
# Batch 60, loss = 40.9226, recon_loss = 39.5179, kl_loss = 1.4047
# Average loss: 53.0232
# Epoch: 33
# Batch 30, loss = 29.9067, recon_loss = 28.3794, kl_loss = 1.5273
# Batch 60, loss = 48.5332, recon_loss = 47.1929, kl_loss = 1.3403
# Average loss: 51.1407
# Epoch: 34
# Batch 30, loss = 34.7538, recon_loss = 33.1049, kl_loss = 1.6489
# Batch 60, loss = 63.7358, recon_loss = 62.4342, kl_loss = 1.3016
# Average loss: 51.2824
# Epoch: 35
# Batch 30, loss = 73.5876, recon_loss = 72.1080, kl_loss = 1.4796
# Batch 60, loss = 57.7837, recon_loss = 56.3667, kl_loss = 1.4170
# Average loss: 51.5172
# Epoch: 36
# Batch 30, loss = 35.0864, recon_loss = 33.6570, kl_loss = 1.4294
# Batch 60, loss = 49.8932, recon_loss = 48.3124, kl_loss = 1.5808
# Average loss: 51.1842
# Epoch: 37
# Batch 30, loss = 53.9118, recon_loss = 52.5244, kl_loss = 1.3875
# Batch 60, loss = 44.1979, recon_loss = 42.8021, kl_loss = 1.3958
# Average loss: 51.3134
# Epoch: 38
# Batch 30, loss = 66.8317, recon_loss = 65.6011, kl_loss = 1.2307
# Batch 60, loss = 38.9458, recon_loss = 37.6143, kl_loss = 1.3315
# Average loss: 55.4949
# Epoch: 39
# Batch 30, loss = 49.1946, recon_loss = 47.8470, kl_loss = 1.3476
# Batch 60, loss = 49.8466, recon_loss = 48.5779, kl_loss = 1.2687
# Average loss: 52.8824
# Epoch: 40
# Batch 30, loss = 38.7529, recon_loss = 37.0152, kl_loss = 1.7377
# Batch 60, loss = 52.6644, recon_loss = 51.3409, kl_loss = 1.3235
# Average loss: 50.9703
# Epoch: 41
# Batch 30, loss = 40.9166, recon_loss = 39.3183, kl_loss = 1.5982
# Batch 60, loss = 46.1544, recon_loss = 44.8561, kl_loss = 1.2983
# Average loss: 50.4379
# Epoch: 42
# Batch 30, loss = 35.6480, recon_loss = 34.1671, kl_loss = 1.4809
# Batch 60, loss = 42.5314, recon_loss = 41.1029, kl_loss = 1.4285
# Average loss: 51.8889
# Epoch: 43
# Batch 30, loss = 54.8600, recon_loss = 53.4858, kl_loss = 1.3743
# Batch 60, loss = 45.2459, recon_loss = 43.8402, kl_loss = 1.4058
# Average loss: 50.7998
# Epoch: 44
# Batch 30, loss = 44.7488, recon_loss = 43.3174, kl_loss = 1.4314
# Batch 60, loss = 47.3948, recon_loss = 45.8364, kl_loss = 1.5584
# Average loss: 49.2417
# Epoch: 45
# Batch 30, loss = 50.6345, recon_loss = 49.2675, kl_loss = 1.3670
# Batch 60, loss = 32.0338, recon_loss = 30.5637, kl_loss = 1.4701
# Average loss: 50.8578
# Epoch: 46
# Batch 30, loss = 48.3524, recon_loss = 46.8399, kl_loss = 1.5124
# Batch 60, loss = 45.4974, recon_loss = 44.0925, kl_loss = 1.4049
# Average loss: 48.0857
# Epoch: 47
# Batch 30, loss = 74.5685, recon_loss = 73.2572, kl_loss = 1.3113
# Batch 60, loss = 49.6508, recon_loss = 47.8587, kl_loss = 1.7922
# Average loss: 47.8582
# Epoch: 48
# Batch 30, loss = 32.5372, recon_loss = 30.9080, kl_loss = 1.6291
# Batch 60, loss = 46.0342, recon_loss = 44.6443, kl_loss = 1.3899
# Average loss: 48.3066
# Epoch: 49
# Batch 30, loss = 54.9381, recon_loss = 53.2146, kl_loss = 1.7235
# Batch 60, loss = 65.7133, recon_loss = 63.9377, kl_loss = 1.7755
# Average loss: 46.7784
# Epoch: 50
# Batch 30, loss = 31.1751, recon_loss = 29.3832, kl_loss = 1.7919
# Batch 60, loss = 43.9877, recon_loss = 42.4099, kl_loss = 1.5778
# Average loss: 46.3324
# Epoch: 51
# Batch 30, loss = 59.6189, recon_loss = 58.0718, kl_loss = 1.5471
# Batch 60, loss = 57.5039, recon_loss = 55.7176, kl_loss = 1.7862
# Average loss: 45.9027
# Epoch: 52
# Average loss: 55.6439
# Epoch: 2
# Batch 30, loss = 61.5489, recon_loss = 60.6161, kl_loss = 0.9328
# Batch 60, loss = 59.6471, recon_loss = 58.7449, kl_loss = 0.9022
# Batch 90, loss = 48.1853, recon_loss = 47.3432, kl_loss = 0.8421
# Batch 120, loss = 49.1350, recon_loss = 48.1908, kl_loss = 0.9443
# Batch 150, loss = 58.3261, recon_loss = 57.4850, kl_loss = 0.8411
# Average loss: 54.7544
# Epoch: 3
# Batch 30, loss = 52.7418, recon_loss = 51.9561, kl_loss = 0.7857
# Batch 60, loss = 44.7380, recon_loss = 43.8105, kl_loss = 0.9275
# Batch 90, loss = 52.4146, recon_loss = 51.5900, kl_loss = 0.8246
# Batch 120, loss = 51.6077, recon_loss = 50.7829, kl_loss = 0.8248
# Batch 150, loss = 37.0212, recon_loss = 36.2888, kl_loss = 0.7324
# Average loss: 53.9331
# Epoch: 4
# Batch 30, loss = 71.9106, recon_loss = 70.9348, kl_loss = 0.9758
# Batch 60, loss = 50.7304, recon_loss = 49.8658, kl_loss = 0.8646
# Batch 90, loss = 57.5356, recon_loss = 56.8684, kl_loss = 0.6673
# Batch 120, loss = 60.9314, recon_loss = 60.2533, kl_loss = 0.6781
# Batch 150, loss = 66.7169, recon_loss = 66.0182, kl_loss = 0.6986
# Average loss: 53.0963
# Epoch: 5
# Batch 30, loss = 51.6509, recon_loss = 50.9141, kl_loss = 0.7369
# Batch 60, loss = 43.5761, recon_loss = 42.8855, kl_loss = 0.6906
# Batch 90, loss = 65.6313, recon_loss = 64.4928, kl_loss = 1.1384
# Batch 120, loss = 50.8194, recon_loss = 50.0692, kl_loss = 0.7502
# Batch 150, loss = 46.0662, recon_loss = 45.1322, kl_loss = 0.9340
# Average loss: 50.8171
# Epoch: 6
# Batch 30, loss = 31.6368, recon_loss = 30.4728, kl_loss = 1.1640
# Batch 60, loss = 36.2871, recon_loss = 35.1128, kl_loss = 1.1743
# Batch 90, loss = 33.6430, recon_loss = 32.2957, kl_loss = 1.3473
# Batch 120, loss = 37.8136, recon_loss = 36.4016, kl_loss = 1.4121
# Batch 150, loss = 40.2557, recon_loss = 38.7884, kl_loss = 1.4673
# Average loss: 30.1896
# Epoch: 7
# Batch 30, loss = 20.4259, recon_loss = 19.2710, kl_loss = 1.1549
# Batch 60, loss = 22.9977, recon_loss = 21.8019, kl_loss = 1.1958
# Batch 90, loss = 25.2520, recon_loss = 24.0311, kl_loss = 1.2209
# Batch 120, loss = 22.7230, recon_loss = 21.2217, kl_loss = 1.5013
# Batch 150, loss = 32.8187, recon_loss = 31.4757, kl_loss = 1.3430
# Average loss: 26.7838
# Epoch: 8
# Batch 30, loss = 26.8131, recon_loss = 25.3401, kl_loss = 1.4730
# Batch 60, loss = 23.9063, recon_loss = 22.5830, kl_loss = 1.3233
# Batch 90, loss = 49.6610, recon_loss = 48.4167, kl_loss = 1.2443
# Batch 120, loss = 19.5980, recon_loss = 18.1888, kl_loss = 1.4092
# Batch 150, loss = 14.3707, recon_loss = 13.0397, kl_loss = 1.3310
# Average loss: 25.5865
# Epoch: 9
# Batch 30, loss = 20.0320, recon_loss = 18.8030, kl_loss = 1.2290
# Batch 60, loss = 21.1829, recon_loss = 19.8875, kl_loss = 1.2954
# Batch 90, loss = 28.7786, recon_loss = 27.4490, kl_loss = 1.3296
# Batch 120, loss = 23.8512, recon_loss = 22.0512, kl_loss = 1.8000
# Batch 150, loss = 33.2697, recon_loss = 31.8218, kl_loss = 1.4479
# Average loss: 25.3552
# Epoch: 0
# Batch 30, loss = 1813.6188, recon_loss = 1813.5396, kl_loss = 0.0793
# Batch 60, loss = 1063.3441, recon_loss = 1063.2479, kl_loss = 0.0962
# Average loss: 1589.7752
# Epoch: 1
# Batch 30, loss = 120.6970, recon_loss = 119.9715, kl_loss = 0.7255
# Batch 60, loss = 121.6858, recon_loss = 119.8192, kl_loss = 1.8667
# Average loss: 168.2030
# Epoch: 2
# Batch 30, loss = 95.2112, recon_loss = 93.8057, kl_loss = 1.4055
# Batch 60, loss = 101.3759, recon_loss = 100.1507, kl_loss = 1.2252
# Average loss: 110.9411
# Epoch: 3
# Batch 30, loss = 84.4600, recon_loss = 83.3215, kl_loss = 1.1385
# Batch 60, loss = 113.4000, recon_loss = 112.0350, kl_loss = 1.3650
# Average loss: 108.1726
# Epoch: 4
# Batch 30, loss = 129.0092, recon_loss = 127.3141, kl_loss = 1.6951
# Batch 60, loss = 85.9259, recon_loss = 84.5486, kl_loss = 1.3773
# Average loss: 104.6894
# Epoch: 5
# Batch 30, loss = 113.2409, recon_loss = 111.8794, kl_loss = 1.3615
# Batch 60, loss = 74.7444, recon_loss = 73.7158, kl_loss = 1.0286
# Average loss: 94.1696
# Epoch: 6
# Batch 30, loss = 69.7461, recon_loss = 68.3529, kl_loss = 1.3932
# Batch 60, loss = 64.8091, recon_loss = 62.8251, kl_loss = 1.9840
# Average loss: 64.8947
# Epoch: 7
# Batch 30, loss = 51.5759, recon_loss = 49.8561, kl_loss = 1.7198
# Batch 60, loss = 62.3385, recon_loss = 60.4643, kl_loss = 1.8742
# Average loss: 60.7008
# Epoch: 8
# Batch 30, loss = 46.7770, recon_loss = 44.9572, kl_loss = 1.8198
# Batch 60, loss = 55.2660, recon_loss = 53.3322, kl_loss = 1.9337
# Average loss: 57.9785
# Epoch: 9
# Batch 30, loss = 71.4731, recon_loss = 69.5838, kl_loss = 1.8893
# Batch 60, loss = 56.4399, recon_loss = 54.6609, kl_loss = 1.7790
# Average loss: 55.2220
# Epoch: 0
# Batch 30, loss = 1926.7190, recon_loss = 1926.6788, kl_loss = 0.0402
# Average loss: 2544.5253
# Epoch: 1
# Batch 30, loss = 447.8725, recon_loss = 447.7932, kl_loss = 0.0793
# Average loss: 780.3173
# Epoch: 2
# Batch 30, loss = 207.1790, recon_loss = 206.2212, kl_loss = 0.9579
# Average loss: 237.5526
# Epoch: 3
# Batch 30, loss = 221.3507, recon_loss = 219.9451, kl_loss = 1.4056
# Average loss: 225.3399
# Epoch: 4
# Batch 30, loss = 228.3466, recon_loss = 227.0824, kl_loss = 1.2642
# Average loss: 224.2355
# Epoch: 5
# Batch 30, loss = 213.6692, recon_loss = 212.5925, kl_loss = 1.0767
# Average loss: 224.3879
# Epoch: 6
# Batch 30, loss = 213.4234, recon_loss = 212.4079, kl_loss = 1.0155
# Average loss: 223.5023
# Epoch: 7
# Batch 30, loss = 188.3281, recon_loss = 187.3749, kl_loss = 0.9532
# Average loss: 222.6881
# Epoch: 8
# Batch 30, loss = 179.1800, recon_loss = 178.0888, kl_loss = 1.0913
# Average loss: 220.5962
# Epoch: 9
# Batch 30, loss = 220.6376, recon_loss = 219.2692, kl_loss = 1.3684
# Average loss: 218.7357
# Epoch: 0
# Batch 30, loss = 320.4859, recon_loss = 320.4490, kl_loss = 0.0369
# Batch 60, loss = 56.4022, recon_loss = 56.3578, kl_loss = 0.0444
# Batch 90, loss = 43.1446, recon_loss = 42.9875, kl_loss = 0.1570
# Batch 120, loss = 63.8369, recon_loss = 63.4410, kl_loss = 0.3959
# Batch 150, loss = 61.5036, recon_loss = 61.0919, kl_loss = 0.4118
# Average loss: 153.3174
# Epoch: 1
# Batch 30, loss = 55.2620, recon_loss = 54.9259, kl_loss = 0.3360
# Batch 60, loss = 56.3146, recon_loss = 56.0263, kl_loss = 0.2882
# Batch 90, loss = 56.6562, recon_loss = 56.3849, kl_loss = 0.2712
# Batch 120, loss = 36.2739, recon_loss = 36.0678, kl_loss = 0.2060
# Batch 150, loss = 65.3967, recon_loss = 65.2085, kl_loss = 0.1881
# Average loss: 55.2320
# Epoch: 2
# Batch 30, loss = 56.7762, recon_loss = 56.6223, kl_loss = 0.1539
# Batch 60, loss = 47.7590, recon_loss = 47.6201, kl_loss = 0.1389
# Batch 90, loss = 37.0522, recon_loss = 36.9437, kl_loss = 0.1085
# Batch 120, loss = 58.9270, recon_loss = 58.8005, kl_loss = 0.1265
# Batch 150, loss = 58.5675, recon_loss = 57.5924, kl_loss = 0.9751
# Average loss: 54.5351
# Epoch: 3
# Batch 30, loss = 48.8143, recon_loss = 48.2701, kl_loss = 0.5442
# Batch 60, loss = 54.2530, recon_loss = 53.6313, kl_loss = 0.6216
# Batch 90, loss = 52.8954, recon_loss = 52.3172, kl_loss = 0.5782
# Batch 120, loss = 36.3043, recon_loss = 35.8484, kl_loss = 0.4559
# Batch 150, loss = 61.6301, recon_loss = 60.9016, kl_loss = 0.7285
# Average loss: 52.4300
# Epoch: 4
# Batch 30, loss = 44.7373, recon_loss = 44.1045, kl_loss = 0.6328
# Batch 60, loss = 63.2421, recon_loss = 62.1636, kl_loss = 1.0786
# Batch 90, loss = 67.0227, recon_loss = 66.0859, kl_loss = 0.9368
# Batch 120, loss = 57.4258, recon_loss = 56.5723, kl_loss = 0.8534
# Batch 150, loss = 30.0370, recon_loss = 29.4190, kl_loss = 0.6180
# Average loss: 50.4643
# Epoch: 5
# Batch 30, loss = 35.9998, recon_loss = 35.0656, kl_loss = 0.9343
# Batch 60, loss = 35.4338, recon_loss = 34.1902, kl_loss = 1.2437
# Batch 90, loss = 32.0338, recon_loss = 30.6526, kl_loss = 1.3812
# Batch 120, loss = 25.0099, recon_loss = 23.5095, kl_loss = 1.5004
# Batch 150, loss = 29.6690, recon_loss = 28.0603, kl_loss = 1.6087
# Average loss: 32.8830
# Epoch: 6
# Batch 30, loss = 24.3527, recon_loss = 22.6892, kl_loss = 1.6634
# Batch 60, loss = 21.1652, recon_loss = 19.2453, kl_loss = 1.9200
# Batch 90, loss = 30.5264, recon_loss = 28.6850, kl_loss = 1.8414
# Batch 120, loss = 22.1488, recon_loss = 20.4178, kl_loss = 1.7310
# Batch 150, loss = 25.4611, recon_loss = 23.5464, kl_loss = 1.9147
# Average loss: 27.0188
# Epoch: 7
# Batch 30, loss = 21.6028, recon_loss = 19.6807, kl_loss = 1.9221
# Batch 60, loss = 36.5660, recon_loss = 34.4993, kl_loss = 2.0668
# Batch 90, loss = 24.1231, recon_loss = 22.1590, kl_loss = 1.9641
# Batch 120, loss = 24.6800, recon_loss = 22.6644, kl_loss = 2.0156
# Batch 150, loss = 36.4055, recon_loss = 34.4922, kl_loss = 1.9133
# Average loss: 26.3410
# Epoch: 8
# Batch 30, loss = 24.4943, recon_loss = 22.5864, kl_loss = 1.9079
# Batch 60, loss = 32.6356, recon_loss = 30.6248, kl_loss = 2.0108
# Batch 90, loss = 30.5716, recon_loss = 28.6526, kl_loss = 1.9190
# Batch 120, loss = 32.1391, recon_loss = 30.2988, kl_loss = 1.8403
# Batch 150, loss = 18.3182, recon_loss = 16.4139, kl_loss = 1.9043
# Average loss: 25.9484
# Epoch: 9
# Batch 30, loss = 36.9039, recon_loss = 35.0562, kl_loss = 1.8477
# Batch 60, loss = 15.6722, recon_loss = 13.7763, kl_loss = 1.8960
# Batch 90, loss = 25.3896, recon_loss = 23.4582, kl_loss = 1.9314
# Batch 120, loss = 23.6755, recon_loss = 21.6825, kl_loss = 1.9930
# Batch 150, loss = 30.6574, recon_loss = 28.8215, kl_loss = 1.8359
# Average loss: 25.7031
# Epoch: 10
# Batch 30, loss = 23.2789, recon_loss = 21.4448, kl_loss = 1.8341
# Batch 60, loss = 22.2171, recon_loss = 20.4269, kl_loss = 1.7902
# Batch 90, loss = 19.0852, recon_loss = 17.3902, kl_loss = 1.6950
# Batch 120, loss = 36.0537, recon_loss = 34.3161, kl_loss = 1.7376
# Batch 150, loss = 30.1546, recon_loss = 28.4159, kl_loss = 1.7387
# Average loss: 25.1899
# Epoch: 11
# Batch 30, loss = 27.8236, recon_loss = 26.1288, kl_loss = 1.6948
# Batch 60, loss = 31.0662, recon_loss = 29.4708, kl_loss = 1.5955
# Batch 90, loss = 29.4419, recon_loss = 27.8424, kl_loss = 1.5995
# Batch 120, loss = 15.3663, recon_loss = 13.6515, kl_loss = 1.7148
# Batch 150, loss = 18.0329, recon_loss = 16.3892, kl_loss = 1.6437
# Average loss: 25.1408
# Epoch: 12
# Batch 30, loss = 19.4561, recon_loss = 17.9257, kl_loss = 1.5304
# Batch 60, loss = 24.0660, recon_loss = 22.6005, kl_loss = 1.4655
# Batch 90, loss = 27.9185, recon_loss = 26.3790, kl_loss = 1.5395
# Batch 120, loss = 24.8661, recon_loss = 23.3860, kl_loss = 1.4801
# Batch 150, loss = 18.6234, recon_loss = 17.2203, kl_loss = 1.4031
# Average loss: 25.0261
# Epoch: 13
# Batch 30, loss = 23.5009, recon_loss = 21.9761, kl_loss = 1.5248
# Batch 60, loss = 20.8763, recon_loss = 19.4630, kl_loss = 1.4134
# Batch 90, loss = 23.4345, recon_loss = 21.9892, kl_loss = 1.4453
# Batch 120, loss = 20.4509, recon_loss = 19.0781, kl_loss = 1.3728
# Batch 150, loss = 24.0163, recon_loss = 22.6080, kl_loss = 1.4083
# Average loss: 24.8412
# Epoch: 14
# Batch 30, loss = 29.9750, recon_loss = 28.5898, kl_loss = 1.3852
# Batch 60, loss = 28.0143, recon_loss = 26.5069, kl_loss = 1.5074
# Batch 90, loss = 20.7975, recon_loss = 19.3593, kl_loss = 1.4382
# Batch 120, loss = 20.7297, recon_loss = 19.3829, kl_loss = 1.3468
# Batch 150, loss = 24.5450, recon_loss = 23.1461, kl_loss = 1.3989
# Average loss: 24.8676
# Epoch: 15
# Batch 30, loss = 23.0799, recon_loss = 21.6299, kl_loss = 1.4500
# Batch 60, loss = 31.0035, recon_loss = 29.6418, kl_loss = 1.3616
# Batch 90, loss = 21.8694, recon_loss = 20.5542, kl_loss = 1.3151
# Batch 120, loss = 19.2439, recon_loss = 17.8960, kl_loss = 1.3479
# Batch 150, loss = 25.8453, recon_loss = 24.4019, kl_loss = 1.4434
# Average loss: 24.8033
# Epoch: 16
# Batch 30, loss = 21.6052, recon_loss = 20.2177, kl_loss = 1.3875
# Batch 60, loss = 23.5095, recon_loss = 22.0748, kl_loss = 1.4347
# Batch 90, loss = 22.6971, recon_loss = 21.3587, kl_loss = 1.3384
# Batch 120, loss = 25.8414, recon_loss = 24.5074, kl_loss = 1.3340
# Batch 150, loss = 14.3257, recon_loss = 13.0471, kl_loss = 1.2787
# Average loss: 24.7083
# Epoch: 17
# Batch 30, loss = 25.1474, recon_loss = 23.7673, kl_loss = 1.3801
# Batch 60, loss = 33.1816, recon_loss = 31.8696, kl_loss = 1.3120
# Batch 90, loss = 19.3537, recon_loss = 18.0651, kl_loss = 1.2887
# Batch 120, loss = 22.1202, recon_loss = 20.8118, kl_loss = 1.3084
# Batch 150, loss = 18.8772, recon_loss = 17.4193, kl_loss = 1.4579
# Average loss: 24.4806
# Epoch: 18
# Batch 30, loss = 19.3084, recon_loss = 17.9163, kl_loss = 1.3921
# Batch 60, loss = 16.9879, recon_loss = 15.7299, kl_loss = 1.2580
# Batch 90, loss = 20.0268, recon_loss = 18.7566, kl_loss = 1.2702
# Batch 120, loss = 20.4807, recon_loss = 19.2068, kl_loss = 1.2739
# Batch 150, loss = 21.9775, recon_loss = 20.7037, kl_loss = 1.2738
# Average loss: 24.6720
# Epoch: 19
# Batch 30, loss = 29.9228, recon_loss = 28.6032, kl_loss = 1.3196
# Batch 60, loss = 23.5932, recon_loss = 22.2847, kl_loss = 1.3085
# Batch 90, loss = 22.0739, recon_loss = 20.7319, kl_loss = 1.3420
# Batch 120, loss = 17.4176, recon_loss = 16.0939, kl_loss = 1.3238
# Batch 150, loss = 19.4016, recon_loss = 18.0893, kl_loss = 1.3122
# Average loss: 24.5913
# Epoch: 20
# Batch 30, loss = 25.3541, recon_loss = 24.0499, kl_loss = 1.3042
# Batch 60, loss = 27.1903, recon_loss = 25.8950, kl_loss = 1.2953
# Batch 90, loss = 21.7464, recon_loss = 20.3830, kl_loss = 1.3634
# Batch 120, loss = 19.0887, recon_loss = 17.7941, kl_loss = 1.2946
# Batch 150, loss = 21.5117, recon_loss = 20.1880, kl_loss = 1.3237
# Average loss: 24.5095
# Epoch: 21
# Batch 30, loss = 21.9045, recon_loss = 20.5928, kl_loss = 1.3117
# Batch 60, loss = 24.5950, recon_loss = 23.3249, kl_loss = 1.2701
# Batch 90, loss = 18.7239, recon_loss = 17.4209, kl_loss = 1.3030
# Batch 120, loss = 20.4547, recon_loss = 19.1654, kl_loss = 1.2893
# Batch 150, loss = 17.0124, recon_loss = 15.7385, kl_loss = 1.2739
# Average loss: 24.5065
# Epoch: 22
# Batch 30, loss = 35.4405, recon_loss = 34.1914, kl_loss = 1.2492
# Batch 60, loss = 20.2428, recon_loss = 18.9350, kl_loss = 1.3078
# Batch 90, loss = 16.7749, recon_loss = 15.4613, kl_loss = 1.3136
# Batch 120, loss = 22.9838, recon_loss = 21.6663, kl_loss = 1.3175
# Batch 150, loss = 25.7959, recon_loss = 24.4602, kl_loss = 1.3357
# Average loss: 24.4604
# Epoch: 23
# Batch 30, loss = 38.3306, recon_loss = 37.0204, kl_loss = 1.3102
# ...
# Batch 120, loss = 23.8680, recon_loss = 22.6145, kl_loss = 1.2535
# Batch 150, loss = 23.0232, recon_loss = 21.8318, kl_loss = 1.1914
# Average loss: 23.6832
# Epoch: 43
# Batch 30, loss = 27.1191, recon_loss = 25.8781, kl_loss = 1.2410
# Batch 60, loss = 16.7214, recon_loss = 15.5413, kl_loss = 1.1801
# Batch 90, loss = 23.4915, recon_loss = 22.2460, kl_loss = 1.2455
# Batch 120, loss = 21.4035, recon_loss = 20.1651, kl_loss = 1.2383
# Batch 150, loss = 32.0754, recon_loss = 30.8894, kl_loss = 1.1860
# Average loss: 23.6267
# Epoch: 44
# Batch 30, loss = 24.8878, recon_loss = 23.6699, kl_loss = 1.2179
# Batch 60, loss = 24.7764, recon_loss = 23.5055, kl_loss = 1.2709
# Batch 90, loss = 23.1863, recon_loss = 21.9128, kl_loss = 1.2735
# Batch 120, loss = 16.2174, recon_loss = 14.9095, kl_loss = 1.3080
# Batch 150, loss = 38.8596, recon_loss = 37.6291, kl_loss = 1.2305
# Average loss: 23.6269
# Epoch: 45
# Batch 30, loss = 25.2409, recon_loss = 24.0655, kl_loss = 1.1754
# Batch 60, loss = 21.3396, recon_loss = 20.0990, kl_loss = 1.2406
# Batch 90, loss = 29.3008, recon_loss = 28.1025, kl_loss = 1.1983
# Batch 120, loss = 28.2346, recon_loss = 26.9761, kl_loss = 1.2585
# Batch 150, loss = 32.1120, recon_loss = 30.8631, kl_loss = 1.2490
# Average loss: 23.5944
# Epoch: 46
# Batch 30, loss = 18.1370, recon_loss = 16.8947, kl_loss = 1.2423
# Batch 60, loss = 24.1581, recon_loss = 22.9154, kl_loss = 1.2427
# Batch 90, loss = 28.5010, recon_loss = 27.2961, kl_loss = 1.2049
# Batch 120, loss = 18.9520, recon_loss = 17.6938, kl_loss = 1.2582
# Batch 150, loss = 25.8723, recon_loss = 24.5727, kl_loss = 1.2996
# Average loss: 23.5824
# Epoch: 47
# Batch 30, loss = 18.5886, recon_loss = 17.3155, kl_loss = 1.2731
# Batch 60, loss = 21.1425, recon_loss = 19.9581, kl_loss = 1.1845
# Batch 90, loss = 23.6559, recon_loss = 22.4704, kl_loss = 1.1856
# Batch 120, loss = 22.9024, recon_loss = 21.6885, kl_loss = 1.2139
# Batch 150, loss = 22.1368, recon_loss = 20.9401, kl_loss = 1.1967
# Average loss: 23.6789
# Epoch: 48
# Batch 30, loss = 17.1317, recon_loss = 15.9042, kl_loss = 1.2276
# Batch 60, loss = 23.9509, recon_loss = 22.7182, kl_loss = 1.2328
# Batch 90, loss = 24.8156, recon_loss = 23.6007, kl_loss = 1.2149
# Batch 120, loss = 24.3537, recon_loss = 23.1460, kl_loss = 1.2077
# Batch 150, loss = 38.8680, recon_loss = 37.6268, kl_loss = 1.2412
# Average loss: 23.6769
# Epoch: 49
# Batch 30, loss = 26.6027, recon_loss = 25.4312, kl_loss = 1.1715
# Batch 60, loss = 25.9264, recon_loss = 24.7120, kl_loss = 1.2144
# Batch 90, loss = 27.8172, recon_loss = 26.6339, kl_loss = 1.1832
# Batch 120, loss = 31.5065, recon_loss = 30.2558, kl_loss = 1.2507
# Batch 150, loss = 27.8872, recon_loss = 26.7020, kl_loss = 1.1852
# Average loss: 23.6631
# Epoch: 50
# Batch 30, loss = 37.2252, recon_loss = 36.0242, kl_loss = 1.2010
# Batch 60, loss = 18.1444, recon_loss = 16.9346, kl_loss = 1.2098
# Batch 90, loss = 21.4394, recon_loss = 20.2300, kl_loss = 1.2093
# Batch 120, loss = 22.2322, recon_loss = 21.0161, kl_loss = 1.2161
# Batch 150, loss = 22.3647, recon_loss = 21.1156, kl_loss = 1.2492
# Average loss: 23.6131
# Epoch: 51
# Batch 30, loss = 25.3914, recon_loss = 24.1429, kl_loss = 1.2485
# Batch 60, loss = 22.9635, recon_loss = 21.7974, kl_loss = 1.1661
# Batch 90, loss = 26.8145, recon_loss = 25.5823, kl_loss = 1.2321
# Batch 120, loss = 21.2289, recon_loss = 20.0272, kl_loss = 1.2017
# Batch 150, loss = 24.8238, recon_loss = 23.5720, kl_loss = 1.2518
# Average loss: 23.5691
# Epoch: 52
# Batch 30, loss = 17.7100, recon_loss = 16.5046, kl_loss = 1.2054
# Batch 60, loss = 28.6105, recon_loss = 27.3486, kl_loss = 1.2619
# Batch 90, loss = 20.6650, recon_loss = 19.3738, kl_loss = 1.2912
# Batch 120, loss = 25.1636, recon_loss = 23.9113, kl_loss = 1.2523
# Batch 150, loss = 18.2858, recon_loss = 17.0748, kl_loss = 1.2110
# Average loss: 23.5963
# Epoch: 53
# Batch 30, loss = 39.8382, recon_loss = 38.5874, kl_loss = 1.2509
# Batch 60, loss = 27.8520, recon_loss = 26.6400, kl_loss = 1.2120
# Batch 90, loss = 27.1120, recon_loss = 25.8608, kl_loss = 1.2512
# Batch 120, loss = 22.4864, recon_loss = 21.2679, kl_loss = 1.2185
# Batch 150, loss = 18.6979, recon_loss = 17.4997, kl_loss = 1.1982
# Average loss: 23.6441
# Epoch: 54
# Batch 30, loss = 34.3488, recon_loss = 33.0871, kl_loss = 1.2618
# Batch 60, loss = 22.7279, recon_loss = 21.5125, kl_loss = 1.2154
# Batch 90, loss = 25.0900, recon_loss = 23.8710, kl_loss = 1.2189
# Batch 120, loss = 18.7460, recon_loss = 17.5330, kl_loss = 1.2130
# Batch 150, loss = 20.6522, recon_loss = 19.4756, kl_loss = 1.1766
# Average loss: 23.6602
# Epoch: 55
# Batch 30, loss = 26.2917, recon_loss = 25.1114, kl_loss = 1.1803
# Batch 60, loss = 24.3528, recon_loss = 23.1745, kl_loss = 1.1782
# Batch 90, loss = 25.0563, recon_loss = 23.8549, kl_loss = 1.2015
# Batch 120, loss = 22.4075, recon_loss = 21.1935, kl_loss = 1.2139
# Batch 150, loss = 21.3244, recon_loss = 20.0923, kl_loss = 1.2321
# Average loss: 23.5929
# Epoch: 56
# Batch 30, loss = 17.8935, recon_loss = 16.6476, kl_loss = 1.2459
# Batch 60, loss = 31.9890, recon_loss = 30.8225, kl_loss = 1.1665
# Batch 90, loss = 28.8649, recon_loss = 27.6595, kl_loss = 1.2055
# Batch 120, loss = 23.5989, recon_loss = 22.4069, kl_loss = 1.1921
# Batch 150, loss = 24.9683, recon_loss = 23.7701, kl_loss = 1.1982
# Average loss: 23.6566
# Epoch: 57
# Batch 30, loss = 25.5548, recon_loss = 24.3054, kl_loss = 1.2494
# Batch 60, loss = 14.1591, recon_loss = 12.9287, kl_loss = 1.2304
# Batch 90, loss = 24.9592, recon_loss = 23.7796, kl_loss = 1.1796
# Batch 120, loss = 32.1246, recon_loss = 30.9026, kl_loss = 1.2220
# Batch 150, loss = 23.8309, recon_loss = 22.6579, kl_loss = 1.1731
# Average loss: 23.5896
# Epoch: 58
# Batch 30, loss = 24.0560, recon_loss = 22.8167, kl_loss = 1.2393
# Batch 60, loss = 28.5211, recon_loss = 27.3378, kl_loss = 1.1834
# Batch 90, loss = 19.2846, recon_loss = 18.0839, kl_loss = 1.2007
# Batch 120, loss = 24.0000, recon_loss = 22.7357, kl_loss = 1.2643
# Batch 150, loss = 30.5295, recon_loss = 29.3205, kl_loss = 1.2091
# Average loss: 23.5984
# Epoch: 59
# Batch 30, loss = 23.1219, recon_loss = 21.9411, kl_loss = 1.1807
# Batch 60, loss = 20.5055, recon_loss = 19.2766, kl_loss = 1.2289
# Batch 90, loss = 25.8372, recon_loss = 24.6282, kl_loss = 1.2090
# Batch 120, loss = 24.0935, recon_loss = 22.8482, kl_loss = 1.2453
# Batch 150, loss = 25.1343, recon_loss = 23.8483, kl_loss = 1.2860
# Average loss: 23.5574
# Epoch: 0
# Batch 30, loss = 2084.3450, recon_loss = 2084.3059, kl_loss = 0.0391
# Batch 60, loss = 1438.6936, recon_loss = 1438.6412, kl_loss = 0.0523
# Average loss: 1888.0875
# Epoch: 1
# Batch 30, loss = 718.6110, recon_loss = 718.4805, kl_loss = 0.1304
# Batch 60, loss = 388.6762, recon_loss = 388.3987, kl_loss = 0.2775
# Average loss: 664.0335
# Epoch: 2
# Batch 30, loss = 124.3870, recon_loss = 123.6216, kl_loss = 0.7654
# Batch 60, loss = 105.1488, recon_loss = 104.4012, kl_loss = 0.7476
# Average loss: 124.6167
# Epoch: 3
# Batch 30, loss = 134.7712, recon_loss = 134.0942, kl_loss = 0.6770
# Batch 60, loss = 98.1518, recon_loss = 97.5545, kl_loss = 0.5973
# Average loss: 110.2154
# Epoch: 4
# Batch 30, loss = 79.8658, recon_loss = 79.3727, kl_loss = 0.4931
# Batch 60, loss = 106.8894, recon_loss = 106.2099, kl_loss = 0.6795
# Average loss: 107.5317
# Epoch: 5
# Batch 30, loss = 97.0267, recon_loss = 96.1476, kl_loss = 0.8791
# Batch 60, loss = 90.0322, recon_loss = 89.1197, kl_loss = 0.9125
# Average loss: 103.8079
# Epoch: 6
# Batch 30, loss = 101.2736, recon_loss = 100.0910, kl_loss = 1.1827
# Batch 60, loss = 91.2844, recon_loss = 90.3279, kl_loss = 0.9566
# Average loss: 101.1432
# Epoch: 7
# Batch 30, loss = 96.4982, recon_loss = 95.5346, kl_loss = 0.9635
# Batch 60, loss = 89.5925, recon_loss = 88.7326, kl_loss = 0.8598
# Average loss: 97.7284
# Epoch: 8
# Batch 30, loss = 94.1598, recon_loss = 92.9390, kl_loss = 1.2208
# Batch 60, loss = 95.1213, recon_loss = 94.2640, kl_loss = 0.8573
# Average loss: 87.4817
# Epoch: 9
# Batch 30, loss = 65.4230, recon_loss = 64.5168, kl_loss = 0.9062
# Batch 60, loss = 46.6154, recon_loss = 45.4833, kl_loss = 1.1321
# Average loss: 57.5940
# Epoch: 10
# Batch 30, loss = 56.4094, recon_loss = 55.3541, kl_loss = 1.0553
# Batch 60, loss = 47.9150, recon_loss = 46.8075, kl_loss = 1.1075
# Average loss: 51.4266
# Epoch: 11
# Batch 30, loss = 44.4781, recon_loss = 43.3363, kl_loss = 1.1419
# Batch 60, loss = 49.0545, recon_loss = 47.8355, kl_loss = 1.2190
# Average loss: 49.7823
# Epoch: 12
# Batch 30, loss = 64.2659, recon_loss = 62.9461, kl_loss = 1.3198
# Batch 60, loss = 54.9466, recon_loss = 53.6135, kl_loss = 1.3332
# Average loss: 49.3548
# Epoch: 13
# Batch 30, loss = 48.0187, recon_loss = 46.6481, kl_loss = 1.3706
# Batch 60, loss = 47.1411, recon_loss = 45.6888, kl_loss = 1.4523
# Average loss: 48.5793
# Epoch: 14
# Batch 30, loss = 44.0289, recon_loss = 42.6235, kl_loss = 1.4054
# Batch 60, loss = 41.1908, recon_loss = 39.8361, kl_loss = 1.3547
# Average loss: 48.0735
# Epoch: 15
# Batch 30, loss = 42.4949, recon_loss = 41.0766, kl_loss = 1.4184
# Batch 60, loss = 42.5199, recon_loss = 41.2942, kl_loss = 1.2256
# Average loss: 47.7174
# Epoch: 16
# Batch 30, loss = 53.1029, recon_loss = 51.5163, kl_loss = 1.5866
# Batch 60, loss = 34.2249, recon_loss = 32.8556, kl_loss = 1.3693
# Average loss: 47.6676
# Epoch: 17
# Batch 30, loss = 48.6237, recon_loss = 47.0944, kl_loss = 1.5294
# Batch 60, loss = 51.1224, recon_loss = 49.6567, kl_loss = 1.4658
# Average loss: 47.3186
# Epoch: 18
# Batch 30, loss = 42.3514, recon_loss = 41.0083, kl_loss = 1.3431
# Batch 60, loss = 49.3340, recon_loss = 47.9475, kl_loss = 1.3865
# Average loss: 47.0591
# Epoch: 19
# Batch 30, loss = 51.5383, recon_loss = 50.1494, kl_loss = 1.3890
# Batch 60, loss = 54.7229, recon_loss = 53.3179, kl_loss = 1.4050
# Average loss: 46.8856
# Epoch: 20
# Batch 30, loss = 51.4937, recon_loss = 49.9581, kl_loss = 1.5356
# Batch 60, loss = 44.3273, recon_loss = 42.8790, kl_loss = 1.4484
# Average loss: 46.6909
# Epoch: 21
# Batch 30, loss = 48.1932, recon_loss = 46.8430, kl_loss = 1.3503
# Batch 60, loss = 43.9733, recon_loss = 42.5796, kl_loss = 1.3937
# Average loss: 46.7105
# Epoch: 22
# Batch 30, loss = 39.6355, recon_loss = 38.2384, kl_loss = 1.3971
# Batch 60, loss = 52.1737, recon_loss = 50.6351, kl_loss = 1.5386
# Average loss: 46.4541
# Epoch: 23
# Batch 30, loss = 52.2042, recon_loss = 50.6317, kl_loss = 1.5725
# Batch 60, loss = 48.2445, recon_loss = 46.7423, kl_loss = 1.5022
# Average loss: 46.4035
# Epoch: 24
# Batch 30, loss = 46.0835, recon_loss = 44.4669, kl_loss = 1.6166
# Batch 60, loss = 41.2734, recon_loss = 39.9540, kl_loss = 1.3193
# Average loss: 46.2819
# Epoch: 25
# Batch 30, loss = 51.9499, recon_loss = 50.4559, kl_loss = 1.4940
# Batch 60, loss = 48.2899, recon_loss = 46.7364, kl_loss = 1.5535
# Average loss: 46.1834
# Epoch: 26
# Batch 30, loss = 42.3071, recon_loss = 40.5203, kl_loss = 1.7868
# Batch 60, loss = 41.3978, recon_loss = 39.8763, kl_loss = 1.5215
# Average loss: 46.0039
# Epoch: 27
# Batch 30, loss = 54.8342, recon_loss = 53.3962, kl_loss = 1.4381
# Batch 60, loss = 46.4875, recon_loss = 44.9073, kl_loss = 1.5802
# Average loss: 46.0198
# Epoch: 28
# Batch 30, loss = 39.2255, recon_loss = 37.7439, kl_loss = 1.4815
# Batch 60, loss = 46.5439, recon_loss = 44.9969, kl_loss = 1.5470
# Average loss: 45.9607
# Epoch: 29
# Batch 30, loss = 40.0509, recon_loss = 38.5637, kl_loss = 1.4873
# Batch 60, loss = 42.3604, recon_loss = 40.9133, kl_loss = 1.4471
# Average loss: 45.7071
# Epoch: 30
# Batch 30, loss = 43.3055, recon_loss = 41.7337, kl_loss = 1.5718
# Batch 60, loss = 40.8942, recon_loss = 39.2779, kl_loss = 1.6164
# Average loss: 45.7292
# Epoch: 31
# Batch 30, loss = 56.7873, recon_loss = 55.2457, kl_loss = 1.5416
# Batch 60, loss = 48.9606, recon_loss = 47.4974, kl_loss = 1.4631
# Average loss: 45.6376
# Epoch: 32
# Batch 30, loss = 55.1488, recon_loss = 53.5656, kl_loss = 1.5831
# Batch 60, loss = 42.8305, recon_loss = 41.3289, kl_loss = 1.5016
# Average loss: 45.4674
# Epoch: 33
# Batch 30, loss = 37.2308, recon_loss = 35.6082, kl_loss = 1.6226
# Batch 60, loss = 35.8667, recon_loss = 34.2503, kl_loss = 1.6164
# Average loss: 45.3947
# Epoch: 34
# Batch 30, loss = 49.4345, recon_loss = 47.8743, kl_loss = 1.5602
# Batch 60, loss = 43.5806, recon_loss = 42.1082, kl_loss = 1.4725
# Average loss: 45.2248
# Epoch: 35
# Batch 30, loss = 41.9453, recon_loss = 40.4587, kl_loss = 1.4866
# Batch 60, loss = 50.5355, recon_loss = 48.8943, kl_loss = 1.6412
# Average loss: 45.1368
# Epoch: 36
# Batch 30, loss = 34.6722, recon_loss = 33.1304, kl_loss = 1.5418
# Batch 60, loss = 51.5230, recon_loss = 49.9682, kl_loss = 1.5548
# Average loss: 45.0725
# Epoch: 37
# Batch 30, loss = 38.1994, recon_loss = 36.6438, kl_loss = 1.5556
# Batch 60, loss = 44.5946, recon_loss = 43.1058, kl_loss = 1.4888
# Average loss: 44.8502
# Epoch: 38
# Batch 30, loss = 44.2848, recon_loss = 42.8458, kl_loss = 1.4389
# Batch 60, loss = 44.6422, recon_loss = 43.1442, kl_loss = 1.4981
# Average loss: 44.4848
# Epoch: 39
# Batch 30, loss = 37.1209, recon_loss = 35.7148, kl_loss = 1.4061
# Batch 60, loss = 51.1787, recon_loss = 49.6483, kl_loss = 1.5304
# Average loss: 44.1952
# Epoch: 40
# Batch 30, loss = 42.7691, recon_loss = 41.1350, kl_loss = 1.6341
# Batch 60, loss = 52.5486, recon_loss = 50.9771, kl_loss = 1.5715
# Average loss: 44.0106
# Epoch: 41
# Batch 30, loss = 42.1470, recon_loss = 40.5317, kl_loss = 1.6153
# Batch 60, loss = 45.5479, recon_loss = 43.9727, kl_loss = 1.5752
# Average loss: 43.7064
# Epoch: 42
# Batch 30, loss = 42.4857, recon_loss = 40.9347, kl_loss = 1.5509
# Batch 60, loss = 50.0178, recon_loss = 48.3629, kl_loss = 1.6549
# Average loss: 43.3139
# Epoch: 43
# Batch 30, loss = 35.3502, recon_loss = 33.6984, kl_loss = 1.6518
# Batch 60, loss = 31.0722, recon_loss = 29.4636, kl_loss = 1.6085
# Average loss: 43.0217
# Epoch: 44
# Batch 30, loss = 48.5475, recon_loss = 47.0412, kl_loss = 1.5063
# Batch 60, loss = 40.4431, recon_loss = 38.6737, kl_loss = 1.7694
# Average loss: 42.6970
# Epoch: 45
# Batch 30, loss = 38.3453, recon_loss = 36.8000, kl_loss = 1.5453
# Batch 60, loss = 34.4911, recon_loss = 33.0312, kl_loss = 1.4600
# Average loss: 42.2513
# Epoch: 46
# Batch 30, loss = 36.4299, recon_loss = 34.9236, kl_loss = 1.5063
# Batch 60, loss = 49.8803, recon_loss = 48.2958, kl_loss = 1.5845
# Average loss: 41.8760
# Epoch: 47
# Batch 30, loss = 41.5272, recon_loss = 39.8577, kl_loss = 1.6695
# Batch 60, loss = 46.3983, recon_loss = 44.7998, kl_loss = 1.5985
# Average loss: 41.4885
# Epoch: 48
# Batch 30, loss = 37.3165, recon_loss = 35.7087, kl_loss = 1.6077
# Batch 60, loss = 37.7243, recon_loss = 36.0682, kl_loss = 1.6561
# Average loss: 40.9343
# Epoch: 49
# Batch 30, loss = 40.5088, recon_loss = 38.7626, kl_loss = 1.7462
# Batch 60, loss = 46.1245, recon_loss = 44.4656, kl_loss = 1.6589
# Average loss: 40.3837
# Epoch: 50
# Batch 30, loss = 40.6348, recon_loss = 38.9448, kl_loss = 1.6899
# Batch 60, loss = 41.3110, recon_loss = 39.5690, kl_loss = 1.7421
# Average loss: 40.0773
# Epoch: 51
# Batch 30, loss = 37.4216, recon_loss = 35.7197, kl_loss = 1.7019
# Batch 60, loss = 42.1993, recon_loss = 40.4346, kl_loss = 1.7647
# Average loss: 39.2191
# Epoch: 52
# Batch 30, loss = 36.7585, recon_loss = 35.1655, kl_loss = 1.5930
# Batch 60, loss = 40.8450, recon_loss = 38.9841, kl_loss = 1.8609
# Average loss: 39.4557
# Epoch: 53
# Batch 30, loss = 36.8135, recon_loss = 34.9183, kl_loss = 1.8952
# Batch 60, loss = 35.4671, recon_loss = 33.5103, kl_loss = 1.9567
# Average loss: 37.4641
# Epoch: 54
# Batch 30, loss = 27.0594, recon_loss = 25.1102, kl_loss = 1.9492
# Batch 60, loss = 34.2193, recon_loss = 32.2429, kl_loss = 1.9764
# Average loss: 36.3538
# Epoch: 55
# Batch 30, loss = 40.0107, recon_loss = 38.0617, kl_loss = 1.9490
# Batch 60, loss = 39.2258, recon_loss = 37.3570, kl_loss = 1.8688
# Average loss: 35.5177
# Epoch: 56
# Batch 30, loss = 32.7685, recon_loss = 30.6637, kl_loss = 2.1048
# Batch 60, loss = 38.9199, recon_loss = 36.9111, kl_loss = 2.0089
# Average loss: 35.0906
# Epoch: 57
# Batch 30, loss = 43.7701, recon_loss = 41.7859, kl_loss = 1.9842
# Batch 60, loss = 33.9935, recon_loss = 32.0495, kl_loss = 1.9440
# Average loss: 34.4592
# Epoch: 58
# Batch 30, loss = 27.6659, recon_loss = 25.7306, kl_loss = 1.9353
# Batch 60, loss = 33.0399, recon_loss = 31.0660, kl_loss = 1.9738
# Average loss: 33.1639
# Epoch: 59
# Batch 30, loss = 37.4055, recon_loss = 35.4113, kl_loss = 1.9942
# Batch 60, loss = 42.4100, recon_loss = 40.4976, kl_loss = 1.9124
# Average loss: 32.5320

# %%
plt.plot()
