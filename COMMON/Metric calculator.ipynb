# %%
import pandas as pd

# %%
general_path = 'C:/Users/OPTIMUSPRIME/Desktop/Studia/Magisterka/Faints-Prediction/'

# %%
path = 'STL DECOMPOSITION/'
file_name = 'LOWESS_best_model_thresholds_grid_search.tsv'

# %%
path = 'VAE2/CNN/'
file_name = 'CNN_best_model_thresholds_grid_search.tsv'

# %%
path = 'MOVING AVERAGE/'
file_name = 'MA_best_model_thresholds_grid_search.tsv'

# %%
df = pd.read_csv(general_path + path + file_name, delimiter='\t', index_col=False)

# %%
df['Red F2R1P'] = (5 * df['Red Precision'] * df['Red Recall']) / ((4 * df['Red Precision']) + df['Red Recall'])

# %%
df.to_csv(path + file_name, sep='\t', index=False)

# %%
df
# Out:
#       Direct Threshold  Averaged Threshold  Accuracy  Red F1  Red Precision  \
# 0                 0.02               0.020    0.1291  0.2287         0.1291
# 1                 0.02               0.022    0.1291  0.2287         0.1291
# 2                 0.02               0.024    0.1291  0.2287         0.1291
# 3                 0.02               0.026    0.1291  0.2287         0.1291
# 4                 0.02               0.028    0.1291  0.2287         0.1291
# 5                 0.02               0.030    0.1291  0.2287         0.1291
# 6                 0.02               0.032    0.1291  0.2287         0.1291
# 7                 0.02               0.034    0.1291  0.2287         0.1291
# 8                 0.02               0.036    0.1291  0.2287         0.1291
# 9                 0.02               0.038    0.1291  0.2287         0.1291
# 10                0.02               0.040    0.1291  0.2287         0.1291
# ...
