# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3], [4,5,6], 'r-')

# %%
aa = [4,5,5,5]
slownik = dict()
for i in range(1, aa[0]):
    for j in range(1, aa[1]):
        for k in range(1, aa[2]):
            for m in range(1, aa[3]):
                slownik[(i,j,k,m)] = 0

# %%
slownik
# Out:
# {(1, 1, 1, 1): 0,
#  (1, 1, 1, 2): 0,
#  (1, 1, 1, 3): 0,
#  (1, 1, 1, 4): 0,
#  (1, 1, 2, 1): 0,
#  (1, 1, 2, 2): 0,
#  (1, 1, 2, 3): 0,
#  (1, 1, 2, 4): 0,
#  (1, 1, 3, 1): 0,
#  (1, 1, 3, 2): 0,
#  (1, 1, 3, 3): 0,
#  (1, 1, 3, 4): 0,
#  (1, 1, 4, 1): 0,
#  (1, 1, 4, 2): 0,
#  (1, 1, 4, 3): 0,
#  (1, 1, 4, 4): 0,
#  (1, 2, 1, 1): 0,
#  (1, 2, 1, 2): 0,
#  (1, 2, 1, 3): 0,
#  (1, 2, 1, 4): 0,
#  (1, 2, 2, 1): 0,
#  (1, 2, 2, 2): 0,
#  (1, 2, 2, 3): 0,
#  (1, 2, 2, 4): 0,
#  (1, 2, 3, 1): 0,
#  (1, 2, 3, 2): 0,
#  (1, 2, 3, 3): 0,
#  (1, 2, 3, 4): 0,
#  (1, 2, 4, 1): 0,
#  (1, 2, 4, 2): 0,
#  (1, 2, 4, 3): 0,
#  (1, 2, 4, 4): 0,
#  (1, 3, 1, 1): 0,
#  (1, 3, 1, 2): 0,
#  (1, 3, 1, 3): 0,
#  (1, 3, 1, 4): 0,
#  (1, 3, 2, 1): 0,
#  (1, 3, 2, 2): 0,
#  (1, 3, 2, 3): 0,
#  (1, 3, 2, 4): 0,
#  (1, 3, 3, 1): 0,
#  (1, 3, 3, 2): 0,
#  (1, 3, 3, 3): 0,
#  (1, 3, 3, 4): 0,
#  (1, 3, 4, 1): 0,
#  (1, 3, 4, 2): 0,
#  (1, 3, 4, 3): 0,
#  (1, 3, 4, 4): 0,
#  (1, 4, 1, 1): 0,
#  (1, 4, 1, 2): 0,
# ...
